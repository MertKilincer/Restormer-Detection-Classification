# %% [markdown]
# # Fine-Tuning for Blur Restoration

# %%
# !gdown 1Nb7geOuhASq1-vuK3enytyDU9mgjsGFz
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Nb7geOuhASq1-vuK3enytyDU9mgjsGFz
# From (redirected): https://drive.google.com/uc?id=1Nb7geOuhASq1-vuK3enytyDU9mgjsGFz&confirm=t&uuid=b1c871e5-1c4d-4ca2-84eb-2af446153b6d
# To: /content/subset.zip
# 100% 26.7G/26.7G [06:30<00:00, 68.5MB/s]

# %%
# !unzip subset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: subset/labels/test/01_06_00_00_073.txt
#   inflating: subset/labels/test/01_39_07_02_283.txt
#   inflating: subset/labels/test/01_21_00_00_238.txt
#   inflating: subset/labels/test/01_31_09_02_151.txt
#   inflating: subset/labels/test/01_06_02_01_105.txt
#   inflating: subset/labels/test/01_21_00_00_103.txt
#   inflating: subset/labels/test/01_08_06_01_011.txt
#   inflating: subset/labels/test/01_21_06_01_207.txt
#   inflating: subset/labels/test/01_08_06_01_268.txt
#   inflating: subset/labels/test/01_06_00_00_054.txt
#   inflating: subset/labels/test/01_07_02_02_080.txt
#   inflating: subset/labels/test/01_04_07_02_165.txt
#   inflating: subset/labels/test/01_08_06_01_215.txt
#   inflating: subset/labels/test/01_24_02_01_194.txt
#   inflating: subset/labels/test/01_08_07_02_189.txt
#   inflating: subset/labels/test/01_39_00_00_172.txt
#   inflating: subset/labels/test/01_39_07_02_113.txt
#   inflating: subset/labels/test/01_24_00_00_212.txt
#   inflating: subset/labels/test/01_39_09_01_261.txt
#   inflating: subset/labels/test/01_05_07_01_044.txt
#   inflating: subset/labels/test/01_24_06_02_002.txt
#   inflating: subset/labels/test/01_31_09_01_173.txt
#   inflating: subset/labels/test/01_39_07_01_126.txt
#   inflating: subset/labels/test/01_07_07_02_298.txt
#   inflating: subset/labels/test/01_06_09_01_117.txt
#   inflating: subset/labels/test/01_24_09_02_099.txt
#   inflating: subset/labels/test/01_41_02_01_221.txt
#   inflating: subset/labels/test/01_08_00_00_232.txt
#   inflating: subset/labels/test/01_24_09_02_165.txt
#   inflating: subset/labels/test/01_24_07_02_181.txt
#   inflating: subset/labels/test/01_41_07_02_283.txt
#   inflating: subset/labels/test/01_26_02_02_046.txt
#   inflating: subset/labels/test/01_07_00_00_273.txt
#   inflating: subset/labels/test/01_24_07_02_082.txt
#   inflating: subset/labels/test/01_21_06_02_283.txt
#   inflating: subset/labels/test/01_38_00_00_237.txt
#   inflating: subset/labels/test/01_41_07_01_167.txt
#   inflating: subset/labels/test/01_05_06_01_064.txt
#   inflating: subset/labels/test/01_31_07_02_200.txt
#   inflating: subset/labels/test/01_06_06_01_220.txt
#   inflating: subset/labels/test/01_38_00_00_218.txt
#   inflating: subset/labels/test/01_24_02_02_145.txt
#   inflating: subset/labels/test/01_41_07_01_199.txt
#   inflating: subset/labels/test/01_41_07_02_125.txt
#   inflating: subset/labels/test/01_21_00_00_094.txt
#   inflating: subset/labels/test/01_24_07_02_121.txt
#   inflating: subset/labels/test/01_04_07_02_029.txt
#   inflating: subset/labels/test/01_07_06_02_263.txt
#   inflating: subset/labels/test/01_39_07_01_203.txt
#   inflating: subset/labels/test/01_21_06_02_229.txt
#   inflating: subset/labels/test/01_06_00_00_079.txt
#   inflating: subset/labels/test/01_06_09_01_113.txt
#   inflating: subset/labels/test/01_26_09_02_239.txt
#   inflating: subset/labels/test/01_47_02_01_267.txt
#   inflating: subset/labels/test/01_26_06_02_052.txt
#   inflating: subset/labels/test/01_47_07_01_257.txt
#   inflating: subset/labels/test/01_07_02_02_287.txt
#   inflating: subset/labels/test/01_21_06_02_188.txt
#   inflating: subset/labels/test/01_18_07_02_052.txt
#   inflating: subset/labels/test/01_06_07_01_115.txt
#   inflating: subset/labels/test/01_21_09_01_199.txt
#   inflating: subset/labels/test/01_07_02_01_082.txt
#   inflating: subset/labels/test/01_05_06_02_001.txt
#   inflating: subset/labels/test/01_39_09_02_257.txt
#   inflating: subset/labels/test/01_21_06_02_212.txt
#   inflating: subset/labels/test/01_19_06_02_225.txt
#   inflating: subset/labels/test/01_08_09_01_233.txt
#   inflating: subset/labels/test/01_31_00_00_169.txt
#   inflating: subset/labels/test/01_39_02_01_248.txt
#   inflating: subset/labels/test/01_06_07_02_250.txt
#   inflating: subset/labels/test/01_24_07_02_175.txt
#   inflating: subset/labels/test/01_31_07_01_167.txt
#   inflating: subset/labels/test/01_08_09_01_255.txt
#   inflating: subset/labels/test/01_06_07_01_228.txt
#   inflating: subset/labels/test/01_39_00_00_275.txt
#   inflating: subset/labels/test/01_21_09_02_052.txt
#   inflating: subset/labels/test/01_41_02_02_232.txt
#   inflating: subset/labels/test/01_21_00_00_096.txt
#   inflating: subset/labels/test/01_07_06_02_283.txt
#   inflating: subset/labels/test/01_07_09_01_012.txt
#   inflating: subset/labels/test/01_06_09_01_243.txt
#   inflating: subset/labels/test/01_06_02_01_203.txt
#   inflating: subset/labels/test/01_05_06_01_036.txt
#   inflating: subset/labels/test/01_21_07_02_276.txt
#   inflating: subset/labels/test/01_08_07_02_159.txt
#   inflating: subset/labels/test/01_06_07_01_193.txt
#   inflating: subset/labels/test/01_07_07_01_093.txt
#   inflating: subset/labels/test/01_07_09_02_005.txt
#   inflating: subset/labels/test/01_41_07_02_159.txt
#   inflating: subset/labels/test/01_38_02_01_270.txt
#   inflating: subset/labels/test/01_24_00_00_279.txt
#   inflating: subset/labels/test/01_21_06_02_011.txt
#   inflating: subset/labels/test/01_07_09_01_236.txt
#   inflating: subset/labels/test/01_21_09_01_166.txt
#   inflating: subset/labels/test/01_21_09_01_196.txt
#   inflating: subset/labels/test/01_39_07_02_123.txt
#   inflating: subset/labels/test/01_21_09_01_117.txt
#   inflating: subset/labels/test/01_39_09_02_286.txt
#   inflating: subset/labels/test/01_08_02_01_004.txt
#   inflating: subset/labels/test/01_26_02_02_300.txt
#   inflating: subset/labels/test/01_21_07_01_164.txt
#   inflating: subset/labels/test/01_26_06_01_274.txt
#   inflating: subset/labels/test/01_31_07_01_179.txt
#   inflating: subset/labels/test/01_07_02_01_014.txt
#   inflating: subset/labels/test/01_21_07_02_213.txt
#   inflating: subset/labels/test/01_21_02_01_213.txt
#   inflating: subset/labels/test/01_08_02_01_202.txt
#   inflating: subset/labels/test/01_31_00_00_224.txt
#   inflating: subset/labels/test/01_31_06_01_296.txt
#   inflating: subset/labels/test/01_19_00_00_234.txt
#   inflating: subset/labels/test/01_21_02_02_250.txt
#   inflating: subset/labels/test/01_06_07_02_077.txt
#   inflating: subset/labels/test/01_04_09_02_133.txt
#   inflating: subset/labels/test/01_21_06_02_060.txt
#   inflating: subset/labels/test/01_07_09_01_211.txt
#   inflating: subset/labels/test/01_26_09_02_270.txt
#   inflating: subset/labels/test/01_41_09_01_268.txt
#   inflating: subset/labels/test/01_08_02_01_229.txt
#   inflating: subset/labels/test/01_31_02_02_200.txt
#   inflating: subset/labels/test/01_39_02_01_063.txt
#   inflating: subset/labels/test/01_26_06_02_064.txt
#   inflating: subset/labels/test/01_38_02_01_281.txt
#   inflating: subset/labels/test/01_08_06_02_178.txt
#   inflating: subset/labels/test/01_06_07_01_107.txt
#   inflating: subset/labels/test/01_39_02_02_173.txt
#   inflating: subset/labels/test/01_39_09_01_056.txt
#   inflating: subset/labels/test/01_06_06_02_027.txt
#   inflating: subset/labels/test/01_39_00_00_258.txt
#   inflating: subset/labels/test/01_05_09_01_056.txt
#   inflating: subset/labels/test/01_07_06_02_213.txt
#   inflating: subset/labels/test/01_07_00_00_217.txt
#   inflating: subset/labels/test/01_04_09_01_145.txt
#   inflating: subset/labels/test/01_05_02_01_063.txt
#   inflating: subset/labels/test/01_06_02_01_185.txt
#   inflating: subset/labels/test/01_24_07_02_104.txt
#   inflating: subset/labels/test/01_24_06_02_159.txt
#   inflating: subset/labels/test/01_06_00_00_052.txt
#   inflating: subset/labels/test/01_41_02_01_229.txt
#   inflating: subset/labels/test/01_39_02_02_118.txt
#   inflating: subset/labels/test/01_21_07_02_186.txt
#   inflating: subset/labels/test/01_26_02_02_044.txt
#   inflating: subset/labels/test/01_21_06_01_078.txt
#   inflating: subset/labels/test/01_41_07_01_020.txt
#   inflating: subset/labels/test/01_39_09_02_291.txt
#   inflating: subset/labels/test/01_06_02_01_071.txt
#   inflating: subset/labels/test/01_31_02_02_223.txt
#   inflating: subset/labels/test/01_06_06_01_092.txt
#   inflating: subset/labels/test/01_39_02_02_256.txt
#   inflating: subset/labels/test/01_21_02_01_002.txt
#   inflating: subset/labels/test/01_31_09_01_224.txt
#   inflating: subset/labels/test/01_21_06_01_190.txt
#   inflating: subset/labels/test/01_24_02_01_173.txt
#   inflating: subset/labels/test/01_39_00_00_267.txt
#   inflating: subset/labels/test/01_06_06_02_083.txt
#   inflating: subset/labels/test/01_39_00_00_061.txt
#   inflating: subset/labels/test/01_39_09_01_157.txt
#   inflating: subset/labels/test/01_06_09_02_033.txt
#   inflating: subset/labels/test/01_08_07_02_196.txt
#   inflating: subset/labels/test/01_38_07_01_282.txt
#   inflating: subset/labels/test/01_39_07_02_118.txt
#   inflating: subset/labels/test/01_39_02_01_102.txt
#   inflating: subset/labels/test/01_05_09_01_049.txt
#   inflating: subset/labels/test/01_24_02_02_152.txt
#   inflating: subset/labels/test/01_07_02_02_219.txt
#   inflating: subset/labels/test/01_21_06_02_110.txt
#   inflating: subset/labels/test/01_41_06_02_192.txt
#   inflating: subset/labels/test/01_06_07_01_053.txt
#   inflating: subset/labels/test/01_38_02_01_251.txt
#   inflating: subset/labels/test/01_07_07_01_262.txt
#   inflating: subset/labels/test/01_21_02_01_209.txt
#   inflating: subset/labels/test/01_24_09_02_133.txt
#   inflating: subset/labels/test/01_24_00_00_277.txt
#   inflating: subset/labels/test/01_18_09_02_069.txt
#   inflating: subset/labels/test/01_21_09_02_196.txt
#   inflating: subset/labels/test/01_41_02_02_247.txt
#   inflating: subset/labels/test/01_24_09_02_300.txt
#   inflating: subset/labels/test/01_07_07_02_250.txt
#   inflating: subset/labels/test/01_05_06_01_007.txt
#   inflating: subset/labels/test/01_24_09_02_183.txt
#   inflating: subset/labels/test/01_41_07_02_287.txt
#   inflating: subset/labels/test/01_21_02_01_181.txt
#   inflating: subset/labels/test/01_31_07_01_232.txt
#   inflating: subset/labels/test/01_08_02_01_238.txt
#   inflating: subset/labels/test/01_07_07_01_189.txt
#   inflating: subset/labels/test/01_07_02_01_230.txt
#   inflating: subset/labels/test/01_05_06_01_060.txt
#   inflating: subset/labels/test/01_07_09_02_266.txt
#   inflating: subset/labels/test/01_24_06_01_283.txt
#   inflating: subset/labels/test/01_07_07_02_069.txt
#   inflating: subset/labels/test/01_26_02_01_042.txt
#   inflating: subset/labels/test/01_31_06_01_150.txt
#   inflating: subset/labels/test/01_38_02_02_299.txt
#   inflating: subset/labels/test/01_41_07_02_279.txt
#   inflating: subset/labels/test/01_24_06_02_287.txt
#   inflating: subset/labels/test/01_07_07_02_237.txt
#   inflating: subset/labels/test/01_38_07_01_255.txt
#   inflating: subset/labels/test/01_06_07_02_241.txt
#   inflating: subset/labels/test/01_21_09_01_102.txt
#   inflating: subset/labels/test/01_41_06_01_015.txt
#   inflating: subset/labels/test/01_04_07_01_165.txt
#   inflating: subset/labels/test/01_08_07_01_206.txt
#   inflating: subset/labels/test/01_39_07_01_147.txt
#   inflating: subset/labels/test/01_21_09_02_113.txt
#   inflating: subset/labels/test/01_38_09_02_249.txt
#   inflating: subset/labels/test/01_31_06_02_219.txt
#   inflating: subset/labels/test/01_38_00_00_238.txt
#   inflating: subset/labels/test/01_08_06_02_212.txt
#   inflating: subset/labels/test/01_04_06_01_165.txt
#   inflating: subset/labels/test/01_04_00_00_048.txt
#   inflating: subset/labels/test/01_41_06_01_254.txt
#   inflating: subset/labels/test/01_39_02_01_190.txt
#   inflating: subset/labels/test/01_21_06_02_251.txt
#   inflating: subset/labels/test/01_18_07_02_071.txt
#   inflating: subset/labels/test/01_04_06_01_157.txt
#   inflating: subset/labels/test/01_26_07_01_278.txt
#   inflating: subset/labels/test/01_24_09_01_048.txt
#   inflating: subset/labels/test/01_26_02_01_241.txt
#   inflating: subset/labels/test/01_39_09_02_057.txt
#   inflating: subset/labels/test/01_47_02_02_256.txt
#   inflating: subset/labels/test/01_06_06_02_230.txt
#   inflating: subset/labels/test/01_24_09_02_049.txt
#   inflating: subset/labels/test/01_05_02_01_051.txt
#   inflating: subset/labels/test/01_18_07_02_050.txt
#   inflating: subset/labels/test/01_07_06_02_017.txt
#   inflating: subset/labels/test/01_07_00_00_206.txt
#   inflating: subset/labels/test/01_24_07_02_287.txt
#   inflating: subset/labels/test/01_24_02_02_279.txt
#   inflating: subset/labels/test/01_39_00_00_142.txt
#   inflating: subset/labels/test/01_21_06_02_137.txt
#   inflating: subset/labels/test/01_18_09_02_048.txt
#   inflating: subset/labels/test/01_26_00_00_045.txt
#   inflating: subset/labels/test/01_41_07_01_152.txt
#   inflating: subset/labels/test/01_06_07_01_144.txt
#   inflating: subset/labels/test/01_21_00_00_271.txt
#   inflating: subset/labels/test/01_24_09_02_120.txt
#   inflating: subset/labels/test/01_04_09_02_027.txt
#   inflating: subset/labels/test/01_06_02_02_176.txt
#   inflating: subset/labels/test/01_21_07_01_161.txt
#   inflating: subset/labels/test/01_06_06_02_196.txt
#   inflating: subset/labels/test/01_07_06_02_066.txt
#   inflating: subset/labels/test/01_39_09_02_107.txt
#   inflating: subset/labels/test/01_07_06_01_230.txt
#   inflating: subset/labels/test/01_08_09_02_255.txt
#   inflating: subset/labels/test/01_31_09_02_187.txt
#   inflating: subset/labels/test/01_41_06_01_233.txt
#   inflating: subset/labels/test/01_39_06_01_159.txt
#   inflating: subset/labels/test/01_04_07_01_036.txt
#   inflating: subset/labels/test/01_04_00_00_298.txt
#   inflating: subset/labels/test/01_21_06_02_148.txt
#   inflating: subset/labels/test/01_26_06_02_238.txt
#   inflating: subset/labels/test/01_08_00_00_257.txt
#   inflating: subset/labels/test/01_18_07_02_001.txt
#   inflating: subset/labels/test/01_26_07_02_260.txt
#   inflating: subset/labels/test/01_07_06_02_200.txt
#   inflating: subset/labels/test/01_31_02_01_197.txt
#   inflating: subset/labels/test/01_24_09_02_150.txt
#   inflating: subset/labels/test/01_21_02_02_192.txt
#   inflating: subset/labels/test/01_21_09_02_263.txt
#   inflating: subset/labels/test/01_24_02_02_130.txt
#   inflating: subset/labels/test/01_39_02_01_195.txt
#   inflating: subset/labels/test/01_06_09_02_207.txt
#   inflating: subset/labels/test/01_06_02_02_127.txt
#   inflating: subset/labels/test/01_21_02_02_226.txt
#   inflating: subset/labels/test/01_24_07_01_088.txt
#   inflating: subset/labels/test/01_06_06_02_053.txt
#   inflating: subset/labels/test/01_08_02_01_006.txt
#   inflating: subset/labels/test/01_41_07_02_173.txt
#   inflating: subset/labels/test/01_39_07_02_243.txt
#   inflating: subset/labels/test/01_26_02_01_059.txt
#   inflating: subset/labels/test/01_21_02_02_134.txt
#   inflating: subset/labels/test/01_39_07_02_134.txt
#   inflating: subset/labels/test/01_07_09_02_013.txt
#   inflating: subset/labels/test/01_39_02_01_156.txt
#   inflating: subset/labels/test/01_39_06_02_260.txt
#   inflating: subset/labels/test/01_21_00_00_231.txt
#   inflating: subset/labels/test/01_24_06_01_102.txt
#   inflating: subset/labels/test/01_41_00_00_218.txt
#   inflating: subset/labels/test/01_39_02_02_125.txt
#   inflating: subset/labels/test/01_24_09_02_137.txt
#   inflating: subset/labels/test/01_21_00_00_008.txt
#   inflating: subset/labels/test/01_06_07_02_096.txt
#   inflating: subset/labels/test/01_21_02_01_144.txt
#   inflating: subset/labels/test/01_19_06_02_226.txt
#   inflating: subset/labels/test/01_07_00_00_067.txt
#   inflating: subset/labels/test/01_24_07_01_287.txt
#   inflating: subset/labels/test/01_21_02_02_061.txt
#   inflating: subset/labels/test/01_07_00_00_069.txt
#   inflating: subset/labels/test/01_31_02_01_177.txt
#   inflating: subset/labels/test/01_21_09_02_170.txt
#   inflating: subset/labels/test/01_39_02_02_292.txt
#   inflating: subset/labels/test/01_24_06_02_271.txt
#   inflating: subset/labels/test/01_21_02_01_005.txt
#   inflating: subset/labels/test/01_31_09_01_219.txt
#   inflating: subset/labels/test/01_07_06_02_236.txt
#   inflating: subset/labels/test/01_19_07_02_205.txt
#   inflating: subset/labels/test/01_47_09_01_256.txt
#   inflating: subset/labels/test/01_24_07_01_122.txt
#   inflating: subset/labels/test/01_21_06_02_053.txt
#   inflating: subset/labels/test/01_08_09_01_180.txt
#   inflating: subset/labels/test/01_06_00_00_194.txt
#   inflating: subset/labels/test/01_24_07_01_066.txt
#   inflating: subset/labels/test/01_31_02_01_224.txt
#   inflating: subset/labels/test/01_41_09_02_208.txt
#   inflating: subset/labels/test/01_19_00_00_210.txt
#   inflating: subset/labels/test/01_21_09_01_041.txt
#   inflating: subset/labels/test/01_05_00_00_036.txt
#   inflating: subset/labels/test/01_21_07_02_174.txt
#   inflating: subset/labels/test/01_06_07_01_112.txt
#   inflating: subset/labels/test/01_24_02_01_290.txt
#   inflating: subset/labels/test/01_21_09_01_134.txt
#   inflating: subset/labels/test/01_39_06_01_169.txt
#   inflating: subset/labels/test/01_47_09_01_266.txt
#   inflating: subset/labels/test/01_08_06_02_278.txt
#   inflating: subset/labels/test/01_39_02_01_171.txt
#   inflating: subset/labels/test/01_06_02_01_043.txt
#   inflating: subset/labels/test/01_24_06_01_279.txt
#   inflating: subset/labels/test/01_39_07_02_269.txt
#   inflating: subset/labels/test/01_08_00_00_175.txt
#   inflating: subset/labels/test/01_26_06_02_241.txt
#   inflating: subset/labels/test/01_06_09_02_140.txt
#   inflating: subset/labels/test/01_04_06_02_129.txt
#   inflating: subset/labels/test/01_38_09_02_215.txt
#   inflating: subset/labels/test/01_21_09_01_264.txt
#   inflating: subset/labels/test/01_41_07_01_269.txt
#   inflating: subset/labels/test/01_24_06_02_099.txt
#   inflating: subset/labels/test/01_19_00_00_222.txt
#   inflating: subset/labels/test/01_24_09_01_187.txt
#   inflating: subset/labels/test/01_31_06_01_158.txt
#   inflating: subset/labels/test/01_21_09_02_003.txt
#   inflating: subset/labels/test/01_21_02_01_060.txt
#   inflating: subset/labels/test/01_38_02_01_240.txt
#   inflating: subset/labels/test/01_21_09_02_224.txt
#   inflating: subset/labels/test/01_24_07_01_280.txt
#   inflating: subset/labels/test/01_41_06_01_262.txt
#   inflating: subset/labels/test/01_08_07_01_268.txt
#   inflating: subset/labels/test/01_31_09_01_155.txt
#   inflating: subset/labels/test/01_04_07_01_156.txt
#   inflating: subset/labels/test/01_41_06_02_238.txt
#   inflating: subset/labels/test/01_24_07_01_106.txt
#   inflating: subset/labels/test/01_05_00_00_053.txt
#   inflating: subset/labels/test/01_26_06_02_257.txt
#   inflating: subset/labels/test/01_21_06_02_102.txt
#   inflating: subset/labels/test/01_41_09_02_164.txt
#   inflating: subset/labels/test/01_24_06_01_156.txt
#   inflating: subset/labels/test/01_04_06_02_137.txt
#   inflating: subset/labels/test/01_39_06_01_271.txt
#   inflating: subset/labels/test/01_24_07_01_177.txt
#   inflating: subset/labels/test/01_38_09_01_245.txt
#   inflating: subset/labels/test/01_04_07_01_157.txt
#   inflating: subset/labels/test/01_18_07_01_065.txt
#   inflating: subset/labels/test/01_41_06_01_168.txt
#   inflating: subset/labels/test/01_08_07_01_198.txt
#   inflating: subset/labels/test/01_21_09_02_160.txt
#   inflating: subset/labels/test/01_07_07_02_184.txt
#   inflating: subset/labels/test/01_38_07_02_267.txt
#   inflating: subset/labels/test/01_31_06_02_156.txt
#   inflating: subset/labels/test/01_08_09_02_280.txt
#   inflating: subset/labels/test/01_39_09_02_267.txt
#   inflating: subset/labels/test/01_21_09_01_216.txt
#   inflating: subset/labels/test/01_18_02_02_051.txt
#   inflating: subset/labels/test/01_24_00_00_213.txt
#   inflating: subset/labels/test/01_39_00_00_244.txt
#   inflating: subset/labels/test/01_39_07_02_204.txt
#   inflating: subset/labels/test/01_18_06_01_070.txt
#   inflating: subset/labels/test/01_07_07_01_222.txt
#   inflating: subset/labels/test/01_04_09_01_157.txt
#   inflating: subset/labels/test/01_07_07_02_228.txt
#   inflating: subset/labels/test/01_21_00_00_270.txt
#   inflating: subset/labels/test/01_39_00_00_284.txt
#   inflating: subset/labels/test/01_24_02_01_284.txt
#   inflating: subset/labels/test/01_39_02_01_119.txt
#   inflating: subset/labels/test/01_07_06_02_048.txt
#   inflating: subset/labels/test/01_21_02_01_132.txt
#   inflating: subset/labels/test/01_24_06_02_189.txt
#   inflating: subset/labels/test/01_39_07_02_129.txt
#   inflating: subset/labels/test/01_38_07_01_209.txt
#   inflating: subset/labels/test/01_24_09_01_064.txt
#   inflating: subset/labels/test/01_24_07_02_100.txt
#   inflating: subset/labels/test/01_39_09_01_189.txt
#   inflating: subset/labels/test/01_24_00_00_057.txt
#   inflating: subset/labels/test/01_06_06_01_215.txt
#   inflating: subset/labels/test/01_21_09_02_137.txt
#   inflating: subset/labels/test/01_41_09_02_142.txt
#   inflating: subset/labels/test/01_08_00_00_203.txt
#   inflating: subset/labels/test/01_31_02_02_179.txt
#   inflating: subset/labels/test/01_26_09_02_300.txt
#   inflating: subset/labels/test/01_06_06_02_181.txt
#   inflating: subset/labels/test/01_24_06_02_103.txt
#   inflating: subset/labels/test/01_26_02_01_046.txt
#   inflating: subset/labels/test/01_26_06_01_061.txt
#   inflating: subset/labels/test/01_08_07_01_007.txt
#   inflating: subset/labels/test/01_24_07_01_274.txt
#   inflating: subset/labels/test/01_06_09_01_054.txt
#   inflating: subset/labels/test/01_41_07_02_210.txt
#   inflating: subset/labels/test/01_41_06_02_262.txt
#   inflating: subset/labels/test/01_19_06_02_200.txt
#   inflating: subset/labels/test/01_39_06_01_062.txt
#   inflating: subset/labels/test/01_24_02_01_141.txt
#   inflating: subset/labels/test/01_08_09_02_284.txt
#   inflating: subset/labels/test/01_04_06_02_017.txt
#   inflating: subset/labels/test/01_06_06_01_038.txt
#   inflating: subset/labels/test/01_41_07_02_245.txt
#   inflating: subset/labels/test/01_41_06_01_242.txt
#   inflating: subset/labels/test/01_05_07_01_043.txt
#   inflating: subset/labels/test/01_24_07_01_185.txt
#   inflating: subset/labels/test/01_31_07_02_231.txt
#   inflating: subset/labels/test/01_26_06_01_247.txt
#   inflating: subset/labels/test/01_39_06_02_135.txt
#   inflating: subset/labels/test/01_07_06_01_217.txt
#   inflating: subset/labels/test/01_06_07_01_054.txt
#   inflating: subset/labels/test/01_39_07_02_103.txt
#   inflating: subset/labels/test/01_19_07_02_189.txt
#   inflating: subset/labels/test/01_26_02_01_297.txt
#   inflating: subset/labels/test/01_31_07_01_211.txt
#   inflating: subset/labels/test/01_24_00_00_138.txt
#   inflating: subset/labels/test/01_06_00_00_178.txt
#   inflating: subset/labels/test/01_24_09_01_295.txt
#   inflating: subset/labels/test/01_47_06_01_259.txt
#   inflating: subset/labels/test/01_07_07_01_048.txt
#   inflating: subset/labels/test/01_05_02_02_040.txt
#   inflating: subset/labels/test/01_26_00_00_237.txt
#   inflating: subset/labels/test/01_06_07_01_086.txt
#   inflating: subset/labels/test/01_41_07_01_267.txt
#   inflating: subset/labels/test/01_21_02_01_176.txt
#   inflating: subset/labels/test/01_07_02_01_176.txt
#   inflating: subset/labels/test/01_41_06_02_237.txt
#   inflating: subset/labels/test/01_08_06_02_161.txt
#   inflating: subset/labels/test/01_26_09_01_065.txt
#   inflating: subset/labels/test/01_18_02_01_046.txt
#   inflating: subset/labels/test/01_41_09_02_264.txt
#   inflating: subset/labels/test/01_08_09_01_156.txt
#   inflating: subset/labels/test/01_26_06_01_249.txt
#   inflating: subset/labels/test/01_05_06_01_020.txt
#   inflating: subset/labels/test/01_26_09_02_237.txt
#   inflating: subset/labels/test/01_07_06_02_282.txt
#   inflating: subset/labels/test/01_06_02_02_219.txt
#   inflating: subset/labels/test/01_39_09_02_161.txt
#   inflating: subset/labels/test/01_21_09_02_086.txt
#   inflating: subset/labels/test/01_21_07_02_037.txt
#   inflating: subset/labels/test/01_41_07_01_123.txt
#   inflating: subset/labels/test/01_06_07_01_222.txt
#   inflating: subset/labels/test/01_41_02_02_271.txt
#   inflating: subset/labels/test/01_26_06_02_065.txt
#   inflating: subset/labels/test/01_38_02_01_199.txt
#   inflating: subset/labels/test/01_21_07_02_280.txt
#   inflating: subset/labels/test/01_38_02_02_210.txt
#   inflating: subset/labels/test/01_21_09_01_204.txt
#   inflating: subset/labels/test/01_21_02_02_081.txt
#   inflating: subset/labels/test/01_39_07_02_278.txt
#   inflating: subset/labels/test/01_31_07_02_195.txt
#   inflating: subset/labels/test/01_41_06_01_201.txt
#   inflating: subset/labels/test/01_31_09_01_150.txt
#   inflating: subset/labels/test/01_38_06_02_255.txt
#   inflating: subset/labels/test/01_24_06_01_012.txt
#   inflating: subset/labels/test/01_05_02_01_013.txt
#   inflating: subset/labels/test/01_06_02_02_221.txt
#   inflating: subset/labels/test/01_06_09_01_131.txt
#   inflating: subset/labels/test/01_08_07_02_218.txt
#   inflating: subset/labels/test/01_05_06_01_079.txt
#   inflating: subset/labels/test/01_41_06_01_255.txt
#   inflating: subset/labels/test/01_39_00_00_277.txt
#   inflating: subset/labels/test/01_24_09_02_019.txt
#   inflating: subset/labels/test/01_06_09_01_135.txt
#   inflating: subset/labels/test/01_06_09_02_029.txt
#   inflating: subset/labels/test/01_21_02_01_101.txt
#   inflating: subset/labels/test/01_24_02_01_184.txt
#   inflating: subset/labels/test/01_47_00_00_265.txt
#   inflating: subset/labels/test/01_26_06_01_234.txt
#   inflating: subset/labels/test/01_21_09_02_206.txt
#   inflating: subset/labels/test/01_07_09_02_188.txt
#   inflating: subset/labels/test/01_06_02_01_237.txt
#   inflating: subset/labels/test/01_21_09_01_261.txt
#   inflating: subset/labels/test/01_07_07_02_213.txt
#   inflating: subset/labels/test/01_39_07_01_182.txt
#   inflating: subset/labels/test/01_38_09_01_285.txt
#   inflating: subset/labels/test/01_41_07_02_215.txt
#   inflating: subset/labels/test/01_08_00_00_183.txt
#   inflating: subset/labels/test/01_18_06_01_006.txt
#   inflating: subset/labels/test/01_39_09_02_174.txt
#   inflating: subset/labels/test/01_06_06_01_105.txt
#   inflating: subset/labels/test/01_05_07_01_063.txt
#   inflating: subset/labels/test/01_21_09_02_260.txt
#   inflating: subset/labels/test/01_07_02_02_085.txt
#   inflating: subset/labels/test/01_31_06_02_296.txt
#   inflating: subset/labels/test/01_19_09_01_191.txt
#   inflating: subset/labels/test/01_26_00_00_295.txt
#   inflating: subset/labels/test/01_21_06_01_110.txt
#   inflating: subset/labels/test/01_24_07_02_092.txt
#   inflating: subset/labels/test/01_24_02_01_094.txt
#   inflating: subset/labels/test/01_06_07_02_121.txt
#   inflating: subset/labels/test/01_24_06_01_201.txt
#   inflating: subset/labels/test/01_41_02_02_130.txt
#   inflating: subset/labels/test/01_05_09_01_012.txt
#   inflating: subset/labels/test/01_21_00_00_226.txt
#   inflating: subset/labels/test/01_26_02_02_006.txt
#   inflating: subset/labels/test/01_26_00_00_020.txt
#   inflating: subset/labels/test/01_21_02_02_127.txt
#   inflating: subset/labels/test/01_26_07_01_263.txt
#   inflating: subset/labels/test/01_08_07_01_001.txt
#   inflating: subset/labels/test/01_21_06_01_136.txt
#   inflating: subset/labels/test/01_39_02_01_196.txt
#   inflating: subset/labels/test/01_24_02_01_101.txt
#   inflating: subset/labels/test/01_19_07_02_225.txt
#   inflating: subset/labels/test/01_38_07_02_297.txt
#   inflating: subset/labels/test/01_21_02_02_171.txt
#   inflating: subset/labels/test/01_24_06_02_180.txt
#   inflating: subset/labels/test/01_39_06_01_187.txt
#   inflating: subset/labels/test/01_19_02_01_189.txt
#   inflating: subset/labels/test/01_05_00_00_011.txt
#   inflating: subset/labels/test/01_06_02_02_141.txt
#   inflating: subset/labels/test/01_24_09_02_135.txt
#   inflating: subset/labels/test/01_21_07_02_001.txt
#   inflating: subset/labels/test/01_41_09_01_150.txt
#   inflating: subset/labels/test/01_39_00_00_190.txt
#   inflating: subset/labels/test/01_21_09_01_215.txt
#   inflating: subset/labels/test/01_04_07_02_145.txt
#   inflating: subset/labels/test/01_38_00_00_270.txt
#   inflating: subset/labels/test/01_41_09_02_177.txt
#   inflating: subset/labels/test/01_41_02_01_279.txt
#   inflating: subset/labels/test/01_08_00_00_171.txt
#   inflating: subset/labels/test/01_39_07_01_103.txt
#   inflating: subset/labels/test/01_41_02_01_184.txt
#   inflating: subset/labels/test/01_08_07_02_224.txt
#   inflating: subset/labels/test/01_26_09_02_056.txt
#   inflating: subset/labels/test/01_07_07_01_215.txt
#   inflating: subset/labels/test/01_07_09_01_189.txt
#   inflating: subset/labels/test/01_21_06_02_213.txt
#   inflating: subset/labels/test/01_08_02_02_155.txt
#   inflating: subset/labels/test/01_05_09_02_064.txt
#   inflating: subset/labels/test/01_38_07_02_220.txt
#   inflating: subset/labels/test/01_24_07_02_096.txt
#   inflating: subset/labels/test/01_04_09_01_043.txt
#   inflating: subset/labels/test/01_08_00_00_017.txt
#   inflating: subset/labels/test/01_31_09_01_176.txt
#   inflating: subset/labels/test/01_38_09_02_283.txt
#   inflating: subset/labels/test/01_18_07_01_084.txt
#   inflating: subset/labels/test/01_41_02_01_233.txt
#   inflating: subset/labels/test/01_26_06_02_240.txt
#   inflating: subset/labels/test/01_24_06_02_086.txt
#   inflating: subset/labels/test/01_05_07_02_046.txt
#   inflating: subset/labels/test/01_19_00_00_203.txt
#   inflating: subset/labels/test/01_07_07_02_079.txt
#   inflating: subset/labels/test/01_39_02_02_268.txt
#   inflating: subset/labels/test/01_31_06_01_152.txt
#   inflating: subset/labels/test/01_21_07_01_097.txt
#   inflating: subset/labels/test/01_08_09_02_271.txt
#   inflating: subset/labels/test/01_04_07_02_014.txt
#   inflating: subset/labels/test/01_24_02_01_207.txt
#   inflating: subset/labels/test/01_07_02_01_279.txt
#   inflating: subset/labels/test/01_24_02_02_056.txt
#   inflating: subset/labels/test/01_21_02_01_110.txt
#   inflating: subset/labels/test/01_21_09_02_050.txt
#   inflating: subset/labels/test/01_31_06_01_212.txt
#   inflating: subset/labels/test/01_08_07_02_269.txt
#   inflating: subset/labels/test/01_06_00_00_045.txt
#   inflating: subset/labels/test/01_21_07_02_059.txt
#   inflating: subset/labels/test/01_39_00_00_171.txt
#   inflating: subset/labels/test/01_19_00_00_229.txt
#   inflating: subset/labels/test/01_06_06_02_044.txt
#   inflating: subset/labels/test/01_19_07_02_195.txt
#   inflating: subset/labels/test/01_26_06_01_064.txt
#   inflating: subset/labels/test/01_05_02_02_027.txt
#   inflating: subset/labels/test/01_07_02_01_191.txt
#   inflating: subset/labels/test/01_31_00_00_213.txt
#   inflating: subset/labels/test/01_39_09_02_248.txt
#   inflating: subset/labels/test/01_18_02_02_088.txt
#   inflating: subset/labels/test/01_31_07_02_300.txt
#   inflating: subset/labels/test/01_26_02_02_045.txt
#   inflating: subset/labels/test/01_21_09_02_268.txt
#   inflating: subset/labels/test/01_24_09_02_023.txt
#   inflating: subset/labels/test/01_24_02_01_143.txt
#   inflating: subset/labels/test/01_07_06_02_196.txt
#   inflating: subset/labels/test/01_26_09_01_007.txt
#   inflating: subset/labels/test/01_07_07_01_279.txt
#   inflating: subset/labels/test/01_41_09_02_134.txt
#   inflating: subset/labels/test/01_07_00_00_005.txt
#   inflating: subset/labels/test/01_21_07_01_036.txt
#   inflating: subset/labels/test/01_38_07_02_245.txt
#   inflating: subset/labels/test/01_08_07_02_270.txt
#   inflating: subset/labels/test/01_21_06_01_161.txt
#   inflating: subset/labels/test/01_06_07_01_232.txt
#   inflating: subset/labels/test/01_26_00_00_232.txt
#   inflating: subset/labels/test/01_05_09_02_024.txt
#   inflating: subset/labels/test/01_07_07_01_065.txt
#   inflating: subset/labels/test/01_06_09_01_074.txt
#   inflating: subset/labels/test/01_39_02_01_246.txt
#   inflating: subset/labels/test/01_21_06_02_087.txt
#   inflating: subset/labels/test/01_06_02_01_210.txt
#   inflating: subset/labels/test/01_39_02_02_060.txt
#   inflating: subset/labels/test/01_39_02_01_001.txt
#   inflating: subset/labels/test/01_18_07_02_084.txt
#   inflating: subset/labels/test/01_04_00_00_170.txt
#   inflating: subset/labels/test/01_41_06_02_282.txt
#   inflating: subset/labels/test/01_24_09_02_278.txt
#   inflating: subset/labels/test/01_21_00_00_191.txt
#   inflating: subset/labels/test/01_19_02_02_215.txt
#   inflating: subset/labels/test/01_41_02_02_137.txt
#   inflating: subset/labels/test/01_19_07_01_230.txt
#   inflating: subset/labels/test/01_39_02_01_209.txt
#   inflating: subset/labels/test/01_31_02_02_165.txt
#   inflating: subset/labels/test/01_38_06_02_202.txt
#   inflating: subset/labels/test/01_04_06_01_042.txt
#   inflating: subset/labels/test/01_05_09_02_006.txt
#   inflating: subset/labels/test/01_39_00_00_145.txt
#   inflating: subset/labels/test/01_24_09_01_169.txt
#   inflating: subset/labels/test/01_26_02_02_013.txt
#   inflating: subset/labels/test/01_24_02_02_264.txt
#   inflating: subset/labels/test/01_08_00_00_168.txt
#   inflating: subset/labels/test/01_24_09_01_123.txt
#   inflating: subset/labels/test/01_39_06_01_115.txt
#   inflating: subset/labels/test/01_07_07_01_219.txt
#   inflating: subset/labels/test/01_31_02_02_174.txt
#   inflating: subset/labels/test/01_05_07_01_008.txt
#   inflating: subset/labels/test/01_38_09_01_249.txt
#   inflating: subset/labels/test/01_06_09_02_038.txt
#   inflating: subset/labels/test/01_41_06_02_193.txt
#   inflating: subset/labels/test/01_21_02_02_149.txt
#   inflating: subset/labels/test/01_39_02_01_121.txt
#   inflating: subset/labels/test/01_47_02_01_273.txt
#   inflating: subset/labels/test/01_06_00_00_046.txt
#   inflating: subset/labels/test/01_06_06_02_071.txt
#   inflating: subset/labels/test/01_24_09_02_080.txt
#   inflating: subset/labels/test/01_06_09_02_214.txt
#   inflating: subset/labels/test/01_07_02_01_264.txt
#   inflating: subset/labels/test/01_39_07_02_097.txt
#   inflating: subset/labels/test/01_07_06_01_181.txt
#   inflating: subset/labels/test/01_39_06_01_163.txt
#   inflating: subset/labels/test/01_41_07_02_177.txt
#   inflating: subset/labels/test/01_21_09_01_018.txt
#   inflating: subset/labels/test/01_41_00_00_019.txt
#   inflating: subset/labels/test/01_08_07_02_155.txt
#   inflating: subset/labels/test/01_19_02_01_238.txt
#   inflating: subset/labels/test/01_26_09_01_252.txt
#   inflating: subset/labels/test/01_24_07_02_155.txt
#   inflating: subset/labels/test/01_18_06_02_066.txt
#   inflating: subset/labels/test/01_08_02_02_256.txt
#   inflating: subset/labels/test/01_24_02_02_131.txt
#   inflating: subset/labels/test/01_31_06_02_297.txt
#   inflating: subset/labels/test/01_07_02_02_009.txt
#   inflating: subset/labels/test/01_04_00_00_156.txt
#   inflating: subset/labels/test/01_21_00_00_290.txt
#   inflating: subset/labels/test/01_06_06_02_135.txt
#   inflating: subset/labels/test/01_21_09_01_246.txt
#   inflating: subset/labels/test/01_41_02_02_014.txt
#   inflating: subset/labels/test/01_21_02_02_291.txt
#   inflating: subset/labels/test/01_08_07_02_010.txt
#   inflating: subset/labels/test/01_05_02_02_007.txt
#   inflating: subset/labels/test/01_24_09_01_046.txt
#   inflating: subset/labels/test/01_38_09_01_223.txt
#   inflating: subset/labels/test/01_24_07_02_159.txt
#   inflating: subset/labels/test/01_18_09_02_005.txt
#   inflating: subset/labels/test/01_18_07_01_078.txt
#   inflating: subset/labels/test/01_24_07_01_132.txt
#   inflating: subset/labels/test/01_06_06_01_237.txt
#   inflating: subset/labels/test/01_07_02_02_187.txt
#   inflating: subset/labels/test/01_31_06_01_178.txt
#   inflating: subset/labels/test/01_08_07_01_190.txt
#   inflating: subset/labels/test/01_06_06_02_043.txt
#   inflating: subset/labels/test/01_06_06_02_024.txt
#   inflating: subset/labels/test/01_06_07_01_225.txt
#   inflating: subset/labels/test/01_24_09_01_108.txt
#   inflating: subset/labels/test/01_04_02_02_129.txt
#   inflating: subset/labels/test/01_26_06_01_253.txt
#   inflating: subset/labels/test/01_19_07_02_207.txt
#   inflating: subset/labels/test/01_07_00_00_187.txt
#   inflating: subset/labels/test/01_21_09_01_072.txt
#   inflating: subset/labels/test/01_39_09_01_165.txt
#   inflating: subset/labels/test/01_06_00_00_146.txt
#   inflating: subset/labels/test/01_06_06_02_192.txt
#   inflating: subset/labels/test/01_08_09_01_016.txt
#   inflating: subset/labels/test/01_21_00_00_118.txt
#   inflating: subset/labels/test/01_24_06_01_066.txt
#   inflating: subset/labels/test/01_21_06_01_087.txt
#   inflating: subset/labels/test/01_21_09_02_217.txt
#   inflating: subset/labels/test/01_26_07_02_270.txt
#   inflating: subset/labels/test/01_08_00_00_272.txt
#   inflating: subset/labels/test/01_41_06_01_275.txt
#   inflating: subset/labels/test/01_24_09_01_113.txt
#   inflating: subset/labels/test/01_07_07_02_236.txt
#   inflating: subset/labels/test/01_08_09_02_162.txt
#   inflating: subset/labels/test/01_04_06_01_043.txt
#   inflating: subset/labels/test/01_08_02_01_187.txt
#   inflating: subset/labels/test/01_05_06_01_081.txt
#   inflating: subset/labels/test/01_38_02_02_238.txt
#   inflating: subset/labels/test/01_38_02_02_227.txt
#   inflating: subset/labels/test/01_07_09_02_244.txt
#   inflating: subset/labels/test/01_08_02_02_166.txt
#   inflating: subset/labels/test/01_06_02_02_099.txt
#   inflating: subset/labels/test/01_06_09_01_208.txt
#   inflating: subset/labels/test/01_24_09_02_122.txt
#   inflating: subset/labels/test/01_08_07_02_156.txt
#   inflating: subset/labels/test/01_06_02_02_040.txt
#   inflating: subset/labels/test/01_38_02_02_245.txt
#   inflating: subset/labels/test/01_24_09_01_163.txt
#   inflating: subset/labels/test/01_07_09_01_293.txt
#   inflating: subset/labels/test/01_21_00_00_169.txt
#   inflating: subset/labels/test/01_39_06_01_285.txt
#   inflating: subset/labels/test/01_24_06_02_186.txt
#   inflating: subset/labels/test/01_39_07_02_247.txt
#   inflating: subset/labels/test/01_04_09_01_177.txt
#   inflating: subset/labels/test/01_21_02_02_204.txt
#   inflating: subset/labels/test/01_06_07_02_247.txt
#   inflating: subset/labels/test/01_21_07_01_271.txt
#   inflating: subset/labels/test/01_06_00_00_129.txt
#   inflating: subset/labels/test/01_26_09_02_053.txt
#   inflating: subset/labels/test/01_47_02_01_256.txt
#   inflating: subset/labels/test/01_41_07_01_226.txt
#   inflating: subset/labels/test/01_38_06_02_219.txt
#   inflating: subset/labels/test/01_39_02_01_272.txt
#   inflating: subset/labels/test/01_04_09_01_298.txt
#   inflating: subset/labels/test/01_21_06_02_226.txt
#   inflating: subset/labels/test/01_06_09_02_190.txt
#   inflating: subset/labels/test/01_18_06_01_046.txt
#   inflating: subset/labels/test/01_24_07_02_135.txt
#   inflating: subset/labels/test/01_31_06_02_198.txt
#   inflating: subset/labels/test/01_19_07_01_217.txt
#   inflating: subset/labels/test/01_31_07_01_221.txt
#   inflating: subset/labels/test/01_41_07_02_208.txt
#   inflating: subset/labels/test/01_31_02_02_229.txt
#   inflating: subset/labels/test/01_18_06_01_004.txt
#   inflating: subset/labels/test/01_41_02_02_150.txt
#   inflating: subset/labels/test/01_31_02_02_187.txt
#   inflating: subset/labels/test/01_24_06_01_276.txt
#   inflating: subset/labels/test/01_26_07_02_003.txt
#   inflating: subset/labels/test/01_38_06_02_214.txt
#   inflating: subset/labels/test/01_06_06_02_086.txt
#   inflating: subset/labels/test/01_39_02_02_264.txt
#   inflating: subset/labels/test/01_21_09_01_112.txt
#   inflating: subset/labels/test/01_24_02_02_166.txt
#   inflating: subset/labels/test/01_24_07_02_152.txt
#   inflating: subset/labels/test/01_39_09_02_203.txt
#   inflating: subset/labels/test/01_21_02_02_084.txt
#   inflating: subset/labels/test/01_07_09_02_204.txt
#   inflating: subset/labels/test/01_24_06_01_101.txt
#   inflating: subset/labels/test/01_41_00_00_259.txt
#   inflating: subset/labels/test/01_39_02_02_136.txt
#   inflating: subset/labels/test/01_38_07_01_215.txt
#   inflating: subset/labels/test/01_05_07_02_017.txt
#   inflating: subset/labels/test/01_04_07_02_175.txt
#   inflating: subset/labels/test/01_26_09_02_242.txt
#   inflating: subset/labels/test/01_19_02_02_235.txt
#   inflating: subset/labels/test/01_18_06_02_094.txt
#   inflating: subset/labels/test/01_39_09_01_150.txt
#   inflating: subset/labels/test/01_21_07_01_121.txt
#   inflating: subset/labels/test/01_24_06_01_111.txt
#   inflating: subset/labels/test/01_26_09_02_059.txt
#   inflating: subset/labels/test/01_08_07_02_278.txt
#   inflating: subset/labels/test/01_18_02_02_064.txt
#   inflating: subset/labels/test/01_21_02_02_114.txt
#   inflating: subset/labels/test/01_31_09_01_300.txt
#   inflating: subset/labels/test/01_38_02_02_233.txt
#   inflating: subset/labels/test/01_19_07_02_202.txt
#   inflating: subset/labels/test/01_04_06_01_298.txt
#   inflating: subset/labels/test/01_38_07_02_255.txt
#   inflating: subset/labels/test/01_38_02_02_214.txt
#   inflating: subset/labels/test/01_21_02_02_023.txt
#   inflating: subset/labels/test/01_41_06_02_252.txt
#   inflating: subset/labels/test/01_24_07_02_122.txt
#   inflating: subset/labels/test/01_31_00_00_196.txt
#   inflating: subset/labels/test/01_08_07_01_289.txt
#   inflating: subset/labels/test/01_31_06_01_187.txt
#   inflating: subset/labels/test/01_24_06_01_115.txt
#   inflating: subset/labels/test/01_41_07_01_205.txt
#   inflating: subset/labels/test/01_07_09_02_245.txt
#   inflating: subset/labels/test/01_31_06_02_201.txt
#   inflating: subset/labels/test/01_39_07_01_172.txt
#   inflating: subset/labels/test/01_07_00_00_064.txt
#   inflating: subset/labels/test/01_18_07_02_079.txt
#   inflating: subset/labels/test/01_26_02_01_265.txt
#   inflating: subset/labels/test/01_07_02_02_217.txt
#   inflating: subset/labels/test/01_19_00_00_240.txt
#   inflating: subset/labels/test/01_38_07_02_293.txt
#   inflating: subset/labels/test/01_06_07_02_210.txt
#   inflating: subset/labels/test/01_39_06_01_260.txt
#   inflating: subset/labels/test/01_06_00_00_088.txt
#   inflating: subset/labels/test/01_18_02_01_072.txt
#   inflating: subset/labels/test/01_08_02_01_239.txt
#   inflating: subset/labels/test/01_07_07_02_287.txt
#   inflating: subset/labels/test/01_24_02_02_076.txt
#   inflating: subset/labels/test/01_04_09_02_034.txt
#   inflating: subset/labels/test/01_31_00_00_300.txt
#   inflating: subset/labels/test/01_39_00_00_146.txt
#   inflating: subset/labels/test/01_26_07_01_018.txt
#   inflating: subset/labels/test/01_06_07_02_189.txt
#   inflating: subset/labels/test/01_05_06_02_053.txt
#   inflating: subset/labels/test/01_04_09_02_016.txt
#   inflating: subset/labels/test/01_19_06_01_210.txt
#   inflating: subset/labels/test/01_39_02_02_141.txt
#   inflating: subset/labels/test/01_38_02_02_230.txt
#   inflating: subset/labels/test/01_31_07_02_167.txt
#   inflating: subset/labels/test/01_26_00_00_297.txt
#   inflating: subset/labels/test/01_06_07_01_028.txt
#   inflating: subset/labels/test/01_38_09_01_229.txt
#   inflating: subset/labels/test/01_19_09_01_203.txt
#   inflating: subset/labels/test/01_08_06_02_010.txt
#   inflating: subset/labels/test/01_08_02_01_233.txt
#   inflating: subset/labels/test/01_21_07_01_282.txt
#   inflating: subset/labels/test/01_26_09_01_292.txt
#   inflating: subset/labels/test/01_05_07_02_044.txt
#   inflating: subset/labels/test/01_24_09_01_106.txt
#   inflating: subset/labels/test/01_31_02_02_166.txt
#   inflating: subset/labels/test/01_38_00_00_263.txt
#   inflating: subset/labels/test/01_41_07_02_146.txt
#   inflating: subset/labels/test/01_38_09_02_299.txt
#   inflating: subset/labels/test/01_31_02_01_295.txt
#   inflating: subset/labels/test/01_21_09_01_001.txt
#   inflating: subset/labels/test/01_06_07_02_065.txt
#   inflating: subset/labels/test/01_08_02_02_007.txt
#   inflating: subset/labels/test/01_38_09_02_202.txt
#   inflating: subset/labels/test/01_08_06_02_256.txt
#   inflating: subset/labels/test/01_39_00_00_152.txt
#   inflating: subset/labels/test/01_06_09_02_173.txt
#   inflating: subset/labels/test/01_39_07_02_174.txt
#   inflating: subset/labels/test/01_08_00_00_201.txt
#   inflating: subset/labels/test/01_07_02_01_265.txt
#   inflating: subset/labels/test/01_38_02_01_252.txt
#   inflating: subset/labels/test/01_24_06_02_128.txt
#   inflating: subset/labels/test/01_24_06_02_110.txt
#   inflating: subset/labels/test/01_47_06_01_270.txt
#   inflating: subset/labels/test/01_39_00_00_156.txt
#   inflating: subset/labels/test/01_07_09_01_049.txt
#   inflating: subset/labels/test/01_41_09_01_247.txt
#   inflating: subset/labels/test/01_08_06_01_231.txt
#   inflating: subset/labels/test/01_06_02_01_142.txt
#   inflating: subset/labels/test/01_05_00_00_021.txt
#   inflating: subset/labels/test/01_21_09_01_180.txt
#   inflating: subset/labels/test/01_06_09_02_123.txt
#   inflating: subset/labels/test/01_18_02_02_079.txt
#   inflating: subset/labels/test/01_26_06_02_033.txt
#   inflating: subset/labels/test/01_08_07_02_233.txt
#   inflating: subset/labels/test/01_38_00_00_216.txt
#   inflating: subset/labels/test/01_47_02_01_258.txt
#   inflating: subset/labels/test/01_41_09_02_010.txt
#   inflating: subset/labels/test/01_41_00_00_212.txt
#   inflating: subset/labels/test/01_21_09_02_024.txt
#   inflating: subset/labels/test/01_05_00_00_010.txt
#   inflating: subset/labels/test/01_41_09_02_187.txt
#   inflating: subset/labels/test/01_06_09_02_119.txt
#   inflating: subset/labels/test/01_18_02_01_074.txt
#   inflating: subset/labels/test/01_31_07_02_173.txt
#   inflating: subset/labels/test/01_24_00_00_011.txt
#   inflating: subset/labels/test/01_26_02_02_232.txt
#   inflating: subset/labels/test/01_07_06_01_189.txt
#   inflating: subset/labels/test/01_26_07_01_295.txt
#   inflating: subset/labels/test/01_41_09_01_132.txt
#   inflating: subset/labels/test/01_24_02_01_053.txt
#   inflating: subset/labels/test/01_21_06_01_246.txt
#   inflating: subset/labels/test/01_31_07_01_212.txt
#   inflating: subset/labels/test/01_31_07_02_229.txt
#   inflating: subset/labels/test/01_07_06_02_300.txt
#   inflating: subset/labels/test/01_21_06_02_150.txt
#   inflating: subset/labels/test/01_41_07_01_184.txt
#   inflating: subset/labels/test/01_38_00_00_278.txt
#   inflating: subset/labels/test/01_07_02_01_093.txt
#   inflating: subset/labels/test/01_19_07_02_193.txt
#   inflating: subset/labels/test/01_04_02_02_140.txt
#   inflating: subset/labels/test/01_21_06_02_057.txt
#   inflating: subset/labels/test/01_07_07_01_184.txt
#   inflating: subset/labels/test/01_31_06_01_297.txt
#   inflating: subset/labels/test/01_39_06_02_172.txt
#   inflating: subset/labels/test/01_21_09_01_290.txt
#   inflating: subset/labels/test/01_21_02_01_193.txt
#   inflating: subset/labels/test/01_41_02_02_234.txt
#   inflating: subset/labels/test/01_38_07_02_229.txt
#   inflating: subset/labels/test/01_24_09_01_073.txt
#   inflating: subset/labels/test/01_21_02_01_136.txt
#   inflating: subset/labels/test/01_05_06_01_048.txt
#   inflating: subset/labels/test/01_21_02_02_099.txt
#   inflating: subset/labels/test/01_24_02_02_093.txt
#   inflating: subset/labels/test/01_26_07_02_001.txt
#   inflating: subset/labels/test/01_38_02_02_294.txt
#   inflating: subset/labels/test/01_21_06_02_238.txt
#   inflating: subset/labels/test/01_39_07_01_247.txt
#   inflating: subset/labels/test/01_41_07_01_228.txt
#   inflating: subset/labels/test/01_08_07_01_238.txt
#   inflating: subset/labels/test/01_06_06_01_102.txt
#   inflating: subset/labels/test/01_24_06_01_176.txt
#   inflating: subset/labels/test/01_24_02_02_169.txt
#   inflating: subset/labels/test/01_21_06_01_048.txt
#   inflating: subset/labels/test/01_06_02_02_071.txt
#   inflating: subset/labels/test/01_06_06_01_225.txt
#   inflating: subset/labels/test/01_21_07_01_020.txt
#   inflating: subset/labels/test/01_08_09_01_012.txt
#   inflating: subset/labels/test/01_41_06_02_214.txt
#   inflating: subset/labels/test/01_21_09_01_203.txt
#   inflating: subset/labels/test/01_08_06_02_154.txt
#   inflating: subset/labels/test/01_41_06_01_291.txt
# ...
#   inflating: subset/labels/test/01_07_07_02_222.txt
#   inflating: subset/labels/test/01_26_00_00_051.txt
#   inflating: subset/labels/test/01_08_06_02_200.txt
#   inflating: subset/labels/test/01_21_09_01_188.txt
#   inflating: subset/labels/test/01_08_06_02_289.txt
#   inflating: subset/labels/test/01_39_07_01_152.txt
#   inflating: subset/labels/test/01_21_00_00_111.txt
#   inflating: subset/labels/test/01_04_07_01_154.txt
#   inflating: subset/labels/test/01_21_07_01_237.txt
#   inflating: subset/labels/test/01_39_02_02_206.txt
#   inflating: subset/labels/test/01_07_02_01_211.txt
#   inflating: subset/labels/test/01_19_07_01_197.txt
#   inflating: subset/labels/test/01_41_07_02_252.txt
#   inflating: subset/labels/test/01_38_09_02_222.txt
#   inflating: subset/labels/test/01_06_09_02_076.txt
#   inflating: subset/labels/test/01_21_09_01_161.txt
#   inflating: subset/labels/test/01_39_02_01_002.txt
#   inflating: subset/labels/test/01_07_07_01_235.txt
#   inflating: subset/labels/test/01_21_02_01_114.txt
#   inflating: subset/labels/test/01_24_02_02_212.txt
#   inflating: subset/labels/test/01_39_02_02_254.txt
#   inflating: subset/labels/test/01_04_06_01_004.txt
#   inflating: subset/labels/test/01_24_09_02_092.txt
#   inflating: subset/labels/test/01_24_02_01_155.txt
#   inflating: subset/labels/test/01_39_09_02_273.txt
#   inflating: subset/labels/test/01_41_06_02_231.txt
#   inflating: subset/labels/test/01_41_02_02_195.txt
#   inflating: subset/labels/test/01_31_09_02_214.txt
#   inflating: subset/labels/test/01_26_09_02_004.txt
#   inflating: subset/labels/test/01_04_07_01_141.txt
#   inflating: subset/labels/test/01_24_07_02_168.txt
#   inflating: subset/labels/test/01_41_02_01_280.txt
#   inflating: subset/labels/test/01_07_06_02_251.txt
#   inflating: subset/labels/test/01_19_09_02_204.txt
#   inflating: subset/labels/test/01_31_06_02_227.txt
#   inflating: subset/labels/test/01_18_07_01_090.txt
#   inflating: subset/labels/test/01_21_09_02_116.txt
#   inflating: subset/labels/test/01_41_06_01_011.txt
#   inflating: subset/labels/test/01_39_00_00_245.txt
#   inflating: subset/labels/test/01_24_00_00_204.txt
#   inflating: subset/labels/test/01_08_06_01_187.txt
#   inflating: subset/labels/test/01_07_02_01_255.txt
#   inflating: subset/labels/test/01_21_07_01_285.txt
#   inflating: subset/labels/test/01_07_09_02_240.txt
#   inflating: subset/labels/test/01_21_07_01_174.txt
#   inflating: subset/labels/test/01_26_00_00_277.txt
#   inflating: subset/labels/test/01_39_06_02_149.txt
#   inflating: subset/labels/test/01_39_09_02_274.txt
#   inflating: subset/labels/test/01_47_09_02_263.txt
#   inflating: subset/labels/test/01_19_06_02_210.txt
#   inflating: subset/labels/test/01_08_09_02_226.txt
#   inflating: subset/labels/test/01_07_02_02_071.txt
#   inflating: subset/labels/test/01_21_02_02_083.txt
#   inflating: subset/labels/test/01_24_07_02_001.txt
#   inflating: subset/labels/test/01_07_06_02_072.txt
#   inflating: subset/labels/test/01_26_02_02_239.txt
#   inflating: subset/labels/test/01_05_06_02_048.txt
#   inflating: subset/labels/test/01_21_07_02_018.txt
#   inflating: subset/labels/test/01_21_07_01_003.txt
#   inflating: subset/labels/test/01_08_02_01_254.txt
#   inflating: subset/labels/test/01_24_07_02_148.txt
#   inflating: subset/labels/test/01_38_09_01_232.txt
#   inflating: subset/labels/test/01_06_06_02_185.txt
#   inflating: subset/labels/test/01_21_06_02_175.txt
#   inflating: subset/labels/test/01_24_07_01_113.txt
#   inflating: subset/labels/test/01_21_07_01_236.txt
#   inflating: subset/labels/test/01_41_07_02_259.txt
#   inflating: subset/labels/test/01_24_00_00_265.txt
#   inflating: subset/labels/test/01_24_06_02_206.txt
#   inflating: subset/labels/test/01_08_02_02_246.txt
#   inflating: subset/labels/test/01_04_02_02_163.txt
#   inflating: subset/labels/test/01_05_06_01_031.txt
#   inflating: subset/labels/test/01_39_09_01_264.txt
#   inflating: subset/labels/test/01_19_02_01_199.txt
#   inflating: subset/labels/test/01_08_06_02_011.txt
#   inflating: subset/labels/test/01_06_02_01_038.txt
#   inflating: subset/labels/test/01_08_02_02_016.txt
#   inflating: subset/labels/test/01_06_07_01_143.txt
#   inflating: subset/labels/test/01_24_09_02_130.txt
#   inflating: subset/labels/test/01_05_09_02_053.txt
#   inflating: subset/labels/test/01_06_09_01_142.txt
#   inflating: subset/labels/test/01_21_00_00_110.txt
#   inflating: subset/labels/test/01_07_02_02_272.txt
#   inflating: subset/labels/test/01_26_02_01_027.txt
#   inflating: subset/labels/test/01_19_07_01_209.txt
#   inflating: subset/labels/test/01_18_06_01_003.txt
#   inflating: subset/labels/test/01_21_00_00_045.txt
#   inflating: subset/labels/test/01_19_09_02_205.txt
#   inflating: subset/labels/test/01_26_02_01_016.txt
#   inflating: subset/labels/test/01_39_07_01_117.txt
#   inflating: subset/labels/test/01_08_06_01_258.txt
#   inflating: subset/labels/test/01_47_07_01_275.txt
#   inflating: subset/labels/test/01_06_02_01_067.txt
#   inflating: subset/labels/test/01_21_00_00_068.txt
#   inflating: subset/labels/test/01_07_00_00_232.txt
#   inflating: subset/labels/test/01_31_02_01_201.txt
#   inflating: subset/labels/test/01_18_02_01_058.txt
#   inflating: subset/labels/test/01_24_02_02_014.txt
#   inflating: subset/labels/test/01_07_06_01_017.txt
#   inflating: subset/labels/test/01_18_09_01_005.txt
#   inflating: subset/labels/test/01_39_00_00_055.txt
#   inflating: subset/labels/test/01_21_09_02_139.txt
#   inflating: subset/labels/test/01_07_06_02_176.txt
#   inflating: subset/labels/test/01_06_06_01_179.txt
#   inflating: subset/labels/test/01_18_02_02_081.txt
#   inflating: subset/labels/test/01_39_06_02_136.txt
#   inflating: subset/labels/test/01_18_07_02_086.txt
#   inflating: subset/labels/test/01_21_09_01_075.txt
#   inflating: subset/labels/test/01_07_07_02_175.txt
#   inflating: subset/labels/test/01_41_02_01_232.txt
#   inflating: subset/labels/test/01_47_09_02_255.txt
#   inflating: subset/labels/test/01_24_09_02_186.txt
#   inflating: subset/labels/test/01_07_09_02_221.txt
#   inflating: subset/labels/test/01_07_07_01_231.txt
#   inflating: subset/labels/test/01_24_00_00_289.txt
#   inflating: subset/labels/test/01_21_07_02_079.txt
#   inflating: subset/labels/test/01_21_09_02_210.txt
#   inflating: subset/labels/test/01_24_02_01_102.txt
#   inflating: subset/labels/test/01_07_09_01_014.txt
#   inflating: subset/labels/test/01_04_07_02_300.txt
#   inflating: subset/labels/test/01_41_06_01_230.txt
#   inflating: subset/labels/test/01_26_06_01_286.txt
#   inflating: subset/labels/test/01_07_02_02_201.txt
#   inflating: subset/labels/test/01_24_00_00_066.txt
#   inflating: subset/labels/test/01_31_00_00_161.txt
#   inflating: subset/labels/test/01_41_02_02_199.txt
#   inflating: subset/labels/test/01_05_06_02_033.txt
#   inflating: subset/labels/test/01_07_07_02_005.txt
#   inflating: subset/labels/test/01_08_02_02_185.txt
#   inflating: subset/labels/test/01_06_07_01_110.txt
#   inflating: subset/labels/test/01_07_00_00_008.txt
#   inflating: subset/labels/test/01_08_02_01_220.txt
#   inflating: subset/labels/test/01_41_06_01_289.txt
#   inflating: subset/labels/test/01_18_02_02_070.txt
#   inflating: subset/labels/test/01_24_06_02_170.txt
#   inflating: subset/labels/test/01_08_00_00_158.txt
#   inflating: subset/labels/test/01_07_02_02_243.txt
#   inflating: subset/labels/test/01_26_00_00_245.txt
#   inflating: subset/labels/test/01_41_06_01_179.txt
#   inflating: subset/labels/test/01_18_07_01_064.txt
#   inflating: subset/labels/test/01_38_00_00_208.txt
#   inflating: subset/labels/test/01_39_02_02_061.txt
#   inflating: subset/labels/test/01_08_06_02_162.txt
#   inflating: subset/labels/test/01_39_09_02_137.txt
#   inflating: subset/labels/test/01_08_06_02_246.txt
#   inflating: subset/labels/test/01_24_02_02_160.txt
#   inflating: subset/labels/test/01_06_07_02_066.txt
#   inflating: subset/labels/test/01_21_02_01_232.txt
#   inflating: subset/labels/test/01_04_02_01_154.txt
#   inflating: subset/labels/test/01_08_00_00_279.txt
#   inflating: subset/labels/test/01_31_02_02_189.txt
#   inflating: subset/labels/test/01_39_06_01_196.txt
#   inflating: subset/labels/test/01_31_06_01_185.txt
#   inflating: subset/labels/test/01_24_09_02_082.txt
#   inflating: subset/labels/test/01_04_06_02_041.txt
#   inflating: subset/labels/test/01_19_07_01_226.txt
#   inflating: subset/labels/test/01_31_02_02_155.txt
#   inflating: subset/labels/test/01_21_02_01_188.txt
#   inflating: subset/labels/test/01_21_09_02_212.txt
#   inflating: subset/labels/test/01_38_00_00_282.txt
#   inflating: subset/labels/test/01_41_06_02_025.txt
#   inflating: subset/labels/test/01_39_02_01_249.txt
#   inflating: subset/labels/test/01_24_06_02_059.txt
#   inflating: subset/labels/test/01_26_07_01_283.txt
#   inflating: subset/labels/test/01_41_06_02_158.txt
#   inflating: subset/labels/test/01_39_09_02_270.txt
#   inflating: subset/labels/test/01_24_09_02_293.txt
#   inflating: subset/labels/test/01_07_09_02_066.txt
#   inflating: subset/labels/test/01_39_06_01_190.txt
#   inflating: subset/labels/test/01_24_09_02_279.txt
#   inflating: subset/labels/test/01_26_06_01_016.txt
#   inflating: subset/labels/test/01_04_02_02_010.txt
#   inflating: subset/labels/test/01_41_06_01_150.txt
#   inflating: subset/labels/test/01_24_07_01_051.txt
#   inflating: subset/labels/test/01_31_07_02_190.txt
#   inflating: subset/labels/test/01_31_02_01_223.txt
#   inflating: subset/labels/test/01_18_07_02_059.txt
#   inflating: subset/labels/test/01_41_07_01_236.txt
#   inflating: subset/labels/test/01_08_00_00_218.txt
#   inflating: subset/labels/test/01_06_07_02_248.txt
#   inflating: subset/labels/test/01_39_02_01_157.txt
#   inflating: subset/labels/test/01_41_00_00_272.txt
#   inflating: subset/labels/test/01_08_02_01_237.txt
#   inflating: subset/labels/test/01_41_02_02_158.txt
#   inflating: subset/labels/test/01_39_02_01_098.txt
#   inflating: subset/labels/test/01_04_09_01_174.txt
#   inflating: subset/labels/test/01_26_09_02_031.txt
#   inflating: subset/labels/test/01_41_02_02_155.txt
#   inflating: subset/labels/test/01_31_00_00_199.txt
#   inflating: subset/labels/test/01_05_09_02_069.txt
#   inflating: subset/labels/test/01_05_09_02_012.txt
#   inflating: subset/labels/test/01_26_07_01_243.txt
#   inflating: subset/labels/test/01_08_00_00_159.txt
#   inflating: subset/labels/test/01_41_02_01_239.txt
#   inflating: subset/labels/test/01_26_07_01_040.txt
#   inflating: subset/labels/test/01_41_09_02_239.txt
#   inflating: subset/labels/test/01_24_02_01_070.txt
#   inflating: subset/labels/test/01_07_06_01_016.txt
#   inflating: subset/labels/test/01_31_09_02_195.txt
#   inflating: subset/labels/test/01_24_02_02_099.txt
#   inflating: subset/labels/test/01_18_06_02_076.txt
#   inflating: subset/labels/test/01_07_07_01_012.txt
#   inflating: subset/labels/test/01_24_02_01_076.txt
#   inflating: subset/labels/test/01_21_06_02_049.txt
#   inflating: subset/labels/test/01_26_02_02_038.txt
#   inflating: subset/labels/test/01_24_07_01_071.txt
#   inflating: subset/labels/test/01_04_06_02_050.txt
#   inflating: subset/labels/test/01_18_07_02_078.txt
#   inflating: subset/labels/test/01_07_02_01_229.txt
#   inflating: subset/labels/test/01_08_09_01_169.txt
#   inflating: subset/labels/test/01_39_09_02_138.txt
#   inflating: subset/labels/test/01_19_09_01_239.txt
#   inflating: subset/labels/test/01_41_06_02_132.txt
#   inflating: subset/labels/test/01_39_02_01_283.txt
#   inflating: subset/labels/test/01_31_02_02_298.txt
#   inflating: subset/labels/test/01_18_06_01_079.txt
#   inflating: subset/labels/test/01_39_06_02_156.txt
#   inflating: subset/labels/test/01_04_09_01_135.txt
#   inflating: subset/labels/test/01_21_02_02_175.txt
#   inflating: subset/labels/test/01_08_07_01_014.txt
#   inflating: subset/labels/test/01_39_06_01_170.txt
#   inflating: subset/labels/test/01_18_09_02_074.txt
#   inflating: subset/labels/test/01_18_09_01_081.txt
#   inflating: subset/labels/test/01_04_02_01_173.txt
#   inflating: subset/labels/test/01_08_02_01_277.txt
#   inflating: subset/labels/test/01_31_09_01_198.txt
#   inflating: subset/labels/test/01_39_09_02_117.txt
#   inflating: subset/labels/test/01_07_07_02_259.txt
#   inflating: subset/labels/test/01_07_06_02_218.txt
#   inflating: subset/labels/test/01_21_09_02_067.txt
#   inflating: subset/labels/test/01_39_02_02_097.txt
#   inflating: subset/labels/test/01_07_02_01_221.txt
#   inflating: subset/labels/test/01_06_00_00_199.txt
#   inflating: subset/labels/test/01_39_06_02_203.txt
#   inflating: subset/labels/test/01_41_00_00_278.txt
#   inflating: subset/labels/test/01_26_02_02_053.txt
#   inflating: subset/labels/test/01_26_06_02_236.txt
#   inflating: subset/labels/test/01_21_07_01_211.txt
#   inflating: subset/labels/test/01_38_09_01_261.txt
#   inflating: subset/labels/test/01_07_00_00_177.txt
#   inflating: subset/labels/test/01_26_06_02_264.txt
#   inflating: subset/labels/test/01_26_00_00_253.txt
#   inflating: subset/labels/test/01_19_00_00_190.txt
#   inflating: subset/labels/test/01_47_07_01_272.txt
#   inflating: subset/labels/test/01_38_02_01_279.txt
#   inflating: subset/labels/test/01_06_02_02_206.txt
#   inflating: subset/labels/test/01_47_07_02_261.txt
#   inflating: subset/labels/test/01_07_00_00_275.txt
#   inflating: subset/labels/test/01_41_09_02_200.txt
#   inflating: subset/labels/test/01_39_00_00_283.txt
#   inflating: subset/labels/test/01_38_09_01_272.txt
#   inflating: subset/labels/test/01_24_06_01_152.txt
#   inflating: subset/labels/test/01_06_07_01_196.txt
#   inflating: subset/labels/test/01_21_07_02_241.txt
#   inflating: subset/labels/test/01_21_07_02_178.txt
#   inflating: subset/labels/test/01_26_07_01_288.txt
#   inflating: subset/labels/test/01_08_09_02_011.txt
#   inflating: subset/labels/test/01_31_06_01_210.txt
#   inflating: subset/labels/test/01_18_06_01_065.txt
#   inflating: subset/labels/test/01_24_09_01_198.txt
#   inflating: subset/labels/test/01_24_06_02_288.txt
#   inflating: subset/labels/test/01_07_02_02_223.txt
#   inflating: subset/labels/test/01_21_00_00_178.txt
#   inflating: subset/labels/test/01_41_00_00_211.txt
#   inflating: subset/labels/test/01_41_02_02_136.txt
#   inflating: subset/labels/test/01_04_02_01_005.txt
#   inflating: subset/labels/test/01_38_07_02_213.txt
#   inflating: subset/labels/test/01_21_07_02_278.txt
#   inflating: subset/labels/test/01_21_07_02_197.txt
#   inflating: subset/labels/test/01_39_02_01_185.txt
#   inflating: subset/labels/test/01_26_06_02_266.txt
#   inflating: subset/labels/test/01_24_07_02_297.txt
#   inflating: subset/labels/test/01_21_06_01_203.txt
#   inflating: subset/labels/test/01_07_09_01_255.txt
#   inflating: subset/labels/test/01_21_06_01_164.txt
#   inflating: subset/labels/test/01_31_09_02_217.txt
#   inflating: subset/labels/test/01_47_09_01_268.txt
#   inflating: subset/labels/test/01_41_00_00_196.txt
#   inflating: subset/labels/test/01_21_09_01_131.txt
#   inflating: subset/labels/test/01_38_02_01_242.txt
#   inflating: subset/labels/test/01_05_09_02_015.txt
#   inflating: subset/labels/test/01_39_02_01_134.txt
#   inflating: subset/labels/test/01_21_02_01_182.txt
#   inflating: subset/labels/test/01_07_00_00_271.txt
#   inflating: subset/labels/test/01_21_06_02_189.txt
#   inflating: subset/labels/test/01_26_06_02_031.txt
#   inflating: subset/labels/test/01_26_06_01_014.txt
#   inflating: subset/labels/test/01_24_02_01_010.txt
#   inflating: subset/labels/test/01_07_09_02_232.txt
#   inflating: subset/labels/test/01_38_07_02_270.txt
#   inflating: subset/labels/test/01_39_09_01_148.txt
#   inflating: subset/labels/test/01_04_06_02_167.txt
#   inflating: subset/labels/test/01_21_02_01_117.txt
#   inflating: subset/labels/test/01_19_07_02_239.txt
#   inflating: subset/labels/test/01_05_07_02_052.txt
#   inflating: subset/labels/test/01_41_06_02_217.txt

# %%
# !gdown 1i3kgZIIQ5nbRKoZwLC_MDatV9ETGcw3l
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1i3kgZIIQ5nbRKoZwLC_MDatV9ETGcw3l
# From (redirected): https://drive.google.com/uc?id=1i3kgZIIQ5nbRKoZwLC_MDatV9ETGcw3l&confirm=t&uuid=bcccd4ae-87f0-417f-badb-36f9ae559eeb
# To: /content/single_image_defocus_deblurring.pth
# 100% 105M/105M [00:02<00:00, 43.8MB/s]

# %% [markdown]
# ## Imports

# %%
import os
import math
import random
import numpy as np
import pandas as pd

from tqdm import tqdm
import cv2
from PIL import Image
import matplotlib.pyplot as plt


import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split

import numbers
from einops import rearrange


random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# %% [markdown]
# ## Dataset Overview
#
# The dataset consists of paired image frames extracted from video sequences.
# Each degraded frame affected by **blur** is paired with its corresponding **clean (no_challenge)** frame from the same sequence and frame index.
#
# This pairing ensures:
# - Perfect spatial alignment
# - Supervised learning with pixel-level correspondence
# - Controlled degradation-specific adaptation
#
# ---
#
# ## Frame Parsing and Pair Construction
#
# Each image filename encodes metadata such as:
# - Sequence ID
# - Challenge type (e.g., rain)
# - Corruption level
# - Frame index
#
# This information is parsed directly from filenames to:
# - Match degraded and clean frames
# - Preserve temporal consistency
# - Separate training and test splits correctly

# %%
import pandas as pd

df = pd.read_csv("subset/classification_labels.csv")

# %%
def parse_frame_info(path):
    name = os.path.basename(path).replace(".jpg", "")
    _, seq, ctype, clevel, frame = name.split("_")
    return seq, int(frame)

df["seq"], df["frame_idx"] = zip(*df["frame"].map(parse_frame_info))
df["split"] = df["frame"].apply(
    lambda x: "test" if "/test/" in x else "train"
)

# %%
def build_pairs(df, expert_name):
    clean = df[df.challenge == "no_challenge"]
    degraded = df[df.challenge == expert_name]

    pairs = degraded.merge(
        clean,
        on=["seq", "frame_idx", "split"],
        suffixes=("_deg", "_clean")
    )

    return pairs

# %% [markdown]
# ## Dataset Splitting Strategy
#
# The paired dataset is divided into:
# - **Training set** – used for optimization
# - **Validation set** – used for early stopping and model selection
# - **Test set** – held out for final evaluation
#
# A validation split is applied only to the training portion to ensure fair evaluation.

# %%
def split_pairs(pairs, val_ratio=0.1, seed=42):
    train_pairs = pairs[pairs.split == "train"].reset_index(drop=True)
    test_pairs  = pairs[pairs.split == "test"].reset_index(drop=True)

    train_pairs, val_pairs = train_test_split(
        train_pairs,
        test_size=val_ratio,
        random_state=seed,
        shuffle=True
    )

    return train_pairs, val_pairs, test_pairs

# %% [markdown]
# ## Patch-Based Training
#
# During training and validation:
# - Random crops are extracted from input–target pairs
# - Cropping improves memory efficiency
# - Encourages spatial generalization
#
# During testing:
# - Full-resolution images are preserved
# - No random cropping is applied

# %%
def random_crop_pair(inp, tgt, crop_size=256):
    w, h = inp.size

    if w < crop_size or h < crop_size:
        return inp, tgt  # fallback

    x = random.randint(0, w - crop_size)
    y = random.randint(0, h - crop_size)

    inp = inp.crop((x, y, x + crop_size, y + crop_size))
    tgt = tgt.crop((x, y, x + crop_size, y + crop_size))

    return inp, tgt

# %% [markdown]
# ## Padding Strategy for Inference
#
# Transformer-based restoration models require spatial dimensions divisible by 8.
# To satisfy this constraint:
# - Images are padded using **reflection padding**
# - Padding avoids introducing artificial borders
# - Outputs are cropped back to original size after inference

# %%
def pad_to_multiple_of_8(img_tensor):
    """
    img_tensor: (B, C, H, W) or (C, H, W)
    Returns padded tensor + original size
    """
    if img_tensor.dim() == 3:
        img_tensor = img_tensor.unsqueeze(0)

    _, _, h, w = img_tensor.shape

    pad_h = (8 - h % 8) % 8
    pad_w = (8 - w % 8) % 8

    padded = F.pad(
        img_tensor,
        (0, pad_w, 0, pad_h),  # (left, right, top, bottom)
        mode="reflect"         # IMPORTANT: no black borders
    )

    return padded, (h, w)

# %% [markdown]
# ## Data Loader Design
#
# Custom PyTorch datasets return:
# - Degraded input image
# - Clean target image
# - Image filename (for saving and visualization)
#
# Data loaders use:
# - Small batch sizes
# - Pin memory for faster GPU transfers
# - Deterministic shuffling for reproducibility

# %%
class RestorationDataset(Dataset):

    def __init__(self, pairs_df, split="train", crop_size=384, max_test_side=512):
        self.df = pairs_df.reset_index(drop=True)
        self.split = split
        self.crop_size = crop_size
        self.max_test_side = max_test_side
        self.to_tensor = T.ToTensor()

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        inp = Image.open(row["frame_deg"]).convert("RGB")
        tgt = Image.open(row["frame_clean"]).convert("RGB")

        if self.split == "train":
            inp, tgt = random_crop_pair(inp, tgt, self.crop_size)

        elif self.split == "val":
            inp, tgt = random_crop_pair(inp, tgt, self.crop_size)


        return {
            "input": self.to_tensor(inp),
            "target": self.to_tensor(tgt),
            "name": os.path.basename(row["frame_deg"])
        }

# %%
blur_pairs = build_pairs(df, "lens_blur")
train_p, val_p, test_p = split_pairs(blur_pairs, val_ratio=0.4)

# %%
train_ds = RestorationDataset(train_p,"train")
val_ds   = RestorationDataset(val_p,"val")
test_ds  = RestorationDataset(test_p,"test")

train_loader = DataLoader(
    train_ds,
    batch_size=2,
    shuffle=True,
    num_workers=2,
    pin_memory=True
)

val_loader = DataLoader(
    val_ds,
    batch_size=1,
    shuffle=False
)

test_loader = DataLoader(
    test_ds,
    batch_size=1,
    shuffle=False
)

# %%
batch = next(iter(train_loader))

inp = batch["input"][0]     # [C,H,W]
tgt = batch["target"][0]


inp_img = T.functional.to_pil_image(inp)
tgt_img = T.functional.to_pil_image(tgt)

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(inp_img)
plt.title(f"Input")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(tgt_img)
plt.title("Target (Clean)")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Restormer Architecture
#
# The restoration backbone is **Restormer**, a transformer optimized for low-level vision tasks.
#
# Key components include:
# - Overlapping patch embedding
# - Multi-DConv Head Transposed Attention (MDTA)
# - Gated Depthwise Feed-Forward Networks (GDFN)
# - Multi-scale encoder–decoder structure
# - Refinement blocks for high-frequency details
#
# This architecture balances global context modeling with local detail preservation.

# %%
# Layer Norm helpers

def to_3d(x):
    return rearrange(x, 'b c h w -> b (h w) c')

def to_4d(x, h, w):
    return rearrange(x, 'b (h w) c -> b c h w', h=h, w=w)

class BiasFree_LayerNorm(nn.Module):
    def __init__(self, normalized_shape):
        super().__init__()
        if isinstance(normalized_shape, numbers.Integral):
            normalized_shape = (normalized_shape,)
        normalized_shape = torch.Size(normalized_shape)
        assert len(normalized_shape) == 1
        self.weight = nn.Parameter(torch.ones(normalized_shape))

    def forward(self, x):
        sigma = x.var(-1, keepdim=True, unbiased=False)
        return x / torch.sqrt(sigma + 1e-5) * self.weight

class WithBias_LayerNorm(nn.Module):
    def __init__(self, normalized_shape):
        super().__init__()
        if isinstance(normalized_shape, numbers.Integral):
            normalized_shape = (normalized_shape,)
        normalized_shape = torch.Size(normalized_shape)
        assert len(normalized_shape) == 1
        self.weight = nn.Parameter(torch.ones(normalized_shape))
        self.bias = nn.Parameter(torch.zeros(normalized_shape))

    def forward(self, x):
        mu = x.mean(-1, keepdim=True)
        sigma = x.var(-1, keepdim=True, unbiased=False)
        return (x - mu) / torch.sqrt(sigma + 1e-5) * self.weight + self.bias

class LayerNorm(nn.Module):
    def __init__(self, dim, LayerNorm_type='WithBias'):
        super().__init__()
        self.body = BiasFree_LayerNorm(dim) if LayerNorm_type == 'BiasFree' else WithBias_LayerNorm(dim)

    def forward(self, x):
        h, w = x.shape[-2:]
        return to_4d(self.body(to_3d(x)), h, w)

# %%
# Gated-Dconv Feed-Forward Network (GDFN)

class FeedForward(nn.Module):
    def __init__(self, dim, ffn_expansion_factor=2.66, bias=False):
        super().__init__()
        hidden_features = int(dim * ffn_expansion_factor)
        self.project_in  = nn.Conv2d(dim, hidden_features * 2, 1, bias=bias)
        self.dwconv      = nn.Conv2d(hidden_features * 2, hidden_features * 2, 3, 1, 1,
                                     groups=hidden_features * 2, bias=bias)
        self.project_out = nn.Conv2d(hidden_features, dim, 1, bias=bias)

    def forward(self, x):
        x = self.project_in(x)
        x1, x2 = self.dwconv(x).chunk(2, dim=1)
        x = F.gelu(x1) * x2
        return self.project_out(x)

# %%
# Multi-DConv Head Transposed Self-Attention (MDTA)

class Attention(nn.Module):
    def __init__(self, dim, num_heads=1, bias=False):
        super().__init__()
        self.num_heads = num_heads
        self.temperature = nn.Parameter(torch.ones(num_heads, 1, 1))

        self.qkv        = nn.Conv2d(dim, dim * 3, 1, bias=bias)
        self.qkv_dwconv = nn.Conv2d(dim * 3, dim * 3, 3, 1, 1, groups=dim * 3, bias=bias)
        self.project_out = nn.Conv2d(dim, dim, 1, bias=bias)

    def forward(self, x):
        b, c, h, w = x.shape

        qkv = self.qkv_dwconv(self.qkv(x))
        q, k, v = qkv.chunk(3, dim=1)

        q = rearrange(q, 'b (head c) h w -> b head c (h w)', head=self.num_heads)
        k = rearrange(k, 'b (head c) h w -> b head c (h w)', head=self.num_heads)
        v = rearrange(v, 'b (head c) h w -> b head c (h w)', head=self.num_heads)

        q = F.normalize(q, dim=-1)
        k = F.normalize(k, dim=-1)

        attn = (q @ k.transpose(-2, -1)) * self.temperature
        attn = attn.softmax(dim=-1)

        out = (attn @ v)
        out = rearrange(out, 'b head c (h w) -> b (head c) h w', head=self.num_heads, h=h, w=w)

        return self.project_out(out)

# %%
# Transformer Block

class TransformerBlock(nn.Module):
    def __init__(self, dim, num_heads, ffn_expansion_factor=2.66, bias=False, LayerNorm_type='WithBias'):
        super().__init__()
        self.norm1 = LayerNorm(dim, LayerNorm_type)
        self.attn  = Attention(dim, num_heads, bias)
        self.norm2 = LayerNorm(dim, LayerNorm_type)
        self.ffn   = FeedForward(dim, ffn_expansion_factor, bias)

    def forward(self, x):
        x = x + self.attn(self.norm1(x))
        x = x + self.ffn(self.norm2(x))
        return x

# %%
# Overlapped patch embed

class OverlapPatchEmbed(nn.Module):
    def __init__(self, in_c=3, embed_dim=48, bias=False):
        super().__init__()
        self.proj = nn.Conv2d(in_c, embed_dim, 3, 1, 1, bias=bias)

    def forward(self, x):
        return self.proj(x)

# %%
# Down/Up sample

class Downsample(nn.Module):
    def __init__(self, n_feat):
        super().__init__()
        self.body = nn.Sequential(
            nn.Conv2d(n_feat, n_feat // 2, 3, 1, 1, bias=False),
            nn.PixelUnshuffle(2)
        )

    def forward(self, x):
        return self.body(x)

class Upsample(nn.Module):
    def __init__(self, n_feat):
        super().__init__()
        self.body = nn.Sequential(
            nn.Conv2d(n_feat, n_feat * 2, 3, 1, 1, bias=False),
            nn.PixelShuffle(2)
        )

    def forward(self, x):
        return self.body(x)

# %%
# Restormer

class Restormer(nn.Module):
    def __init__(
        self,
        inp_channels=3,
        out_channels=3,
        dim=48,
        num_blocks=[4,6,6,8],
        num_refinement_blocks=4,
        heads=[1,2,4,8],
        ffn_expansion_factor=2.66,
        bias=False,
        LayerNorm_type='WithBias',
        dual_pixel_task=False
    ):
        super().__init__()

        self.patch_embed = OverlapPatchEmbed(inp_channels, dim)

        self.encoder_level1 = nn.Sequential(*[
            TransformerBlock(dim, heads[0], ffn_expansion_factor, bias, LayerNorm_type)
            for _ in range(num_blocks[0])
        ])

        self.down1_2 = Downsample(dim)
        self.encoder_level2 = nn.Sequential(*[
            TransformerBlock(int(dim*2**1), heads[1], ffn_expansion_factor, bias, LayerNorm_type)
            for _ in range(num_blocks[1])
        ])

        self.down2_3 = Downsample(int(dim*2**1))
        self.encoder_level3 = nn.Sequential(*[
            TransformerBlock(int(dim*2**2), heads[2], ffn_expansion_factor, bias, LayerNorm_type)
            for _ in range(num_blocks[2])
        ])

        self.down3_4 = Downsample(int(dim*2**2))
        self.latent = nn.Sequential(*[
            TransformerBlock(int(dim*2**3), heads[3], ffn_expansion_factor, bias, LayerNorm_type)
            for _ in range(num_blocks[3])
        ])

        self.up4_3 = Upsample(int(dim*2**3))
        self.reduce_chan_level3 = nn.Conv2d(int(dim*2**3), int(dim*2**2), 1, bias=bias)
        self.decoder_level3 = nn.Sequential(*[
            TransformerBlock(int(dim*2**2), heads[2], ffn_expansion_factor, bias, LayerNorm_type)
            for _ in range(num_blocks[2])
        ])

        self.up3_2 = Upsample(int(dim*2**2))
        self.reduce_chan_level2 = nn.Conv2d(int(dim*2**2), int(dim*2**1), 1, bias=bias)
        self.decoder_level2 = nn.Sequential(*[
            TransformerBlock(int(dim*2**1), heads[1], ffn_expansion_factor, bias, LayerNorm_type)
            for _ in range(num_blocks[1])
        ])

        self.up2_1 = Upsample(int(dim*2**1))
        self.decoder_level1 = nn.Sequential(*[
            TransformerBlock(int(dim*2**1), heads[0], ffn_expansion_factor, bias, LayerNorm_type)
            for _ in range(num_blocks[0])
        ])

        self.refinement = nn.Sequential(*[
            TransformerBlock(int(dim*2**1), heads[0], ffn_expansion_factor, bias, LayerNorm_type)
            for _ in range(num_refinement_blocks)
        ])

        self.dual_pixel_task = dual_pixel_task
        if self.dual_pixel_task:
            self.skip_conv = nn.Conv2d(dim, int(dim*2**1), 1, bias=bias)

        self.output = nn.Conv2d(int(dim*2**1), out_channels, 3, 1, 1, bias=bias)

    def forward(self, inp_img):
        inp_enc_level1 = self.patch_embed(inp_img)
        out_enc_level1 = self.encoder_level1(inp_enc_level1)

        inp_enc_level2 = self.down1_2(out_enc_level1)
        out_enc_level2 = self.encoder_level2(inp_enc_level2)

        inp_enc_level3 = self.down2_3(out_enc_level2)
        out_enc_level3 = self.encoder_level3(inp_enc_level3)

        inp_enc_level4 = self.down3_4(out_enc_level3)
        latent = self.latent(inp_enc_level4)

        inp_dec_level3 = self.up4_3(latent)
        inp_dec_level3 = torch.cat([inp_dec_level3, out_enc_level3], 1)
        inp_dec_level3 = self.reduce_chan_level3(inp_dec_level3)
        out_dec_level3 = self.decoder_level3(inp_dec_level3)

        inp_dec_level2 = self.up3_2(out_dec_level3)
        inp_dec_level2 = torch.cat([inp_dec_level2, out_enc_level2], 1)
        inp_dec_level2 = self.reduce_chan_level2(inp_dec_level2)
        out_dec_level2 = self.decoder_level2(inp_dec_level2)

        inp_dec_level1 = self.up2_1(out_dec_level2)
        inp_dec_level1 = torch.cat([inp_dec_level1, out_enc_level1], 1)
        out_dec_level1 = self.decoder_level1(inp_dec_level1)

        out_dec_level1 = self.refinement(out_dec_level1)

        if self.dual_pixel_task:
            out_dec_level1 = out_dec_level1 + self.skip_conv(inp_enc_level1)
            out_dec_level1 = self.output(out_dec_level1)
        else:
            out_dec_level1 = self.output(out_dec_level1) + inp_img

        return out_dec_level1

# %%
def load_restormer_checkpoint(model, ckpt_path, strict=False):
    ckpt = torch.load(
        ckpt_path,
        map_location="cpu",
        weights_only=False  # IMPORTANT for PyTorch 2.x
    )

    if isinstance(ckpt, dict):
        if "params" in ckpt:
            state = ckpt["params"]
        elif "state_dict" in ckpt:
            state = ckpt["state_dict"]
        else:
            state = ckpt
    else:
        state = ckpt

    missing, unexpected = model.load_state_dict(state, strict=strict)
    print(f"Loaded {ckpt_path} | missing={len(missing)} unexpected={len(unexpected)}")

# %% [markdown]
# ## Pretrained Initialization
#
# The model is initialized using **pretrained expert weights** corresponding to the target degradation type.
#
# This transfer learning strategy:
# - Accelerates convergence
# - Preserves low-level visual priors
# - Reduces the risk of overfitting on small datasets
#
# ---
#
# ## Expert-Specific Loss Design
#
# Loss functions are selected based on the degradation expert.
#
# For **rain restoration**:
# - A pure **L1 reconstruction loss** is used
# - Focuses on removing rain streaks without altering illumination
# - Avoids unnecessary brightness or exposure constraints
#
# This design reflects the localized nature of rain artifacts.
#
# ---
#
# ## Fine-Tuning Strategy
#
# Training follows a **staged unfreezing approach**:
#
# ### Stage 1
# - Encoder is frozen
# - Decoder and refinement blocks are trained
# - Enables task adaptation without disrupting learned representations
#
# ### Stage 2
# - Latent and deeper encoder layers are unfrozen
# - Learning rate is reduced
# - Allows controlled refinement of mid-level features
#
# ---
#
# ## Optimization Setup
#
# Training uses:
# - AdamW optimizer with weight decay
# - Mixed precision (AMP) for memory efficiency
# - Gradient accumulation to simulate larger batch sizes
#
# This setup enables stable training under limited GPU memory.
#
# ---
#
# ## Training Loop
#
# Each training epoch consists of:
# - Forward pass with AMP
# - Loss computation and scaled backpropagation
# - Gradient updates after accumulation steps
#
# Validation is performed after each epoch using:
# - PSNR for reconstruction quality
# - SSIM for structural fidelity
#
# ---
#
# ## Early Stopping Policy
#
# To prevent overfitting:
# - Validation PSNR is monitored
# - Training stops if improvement falls below a threshold
# - Best model checkpoint is saved automatically
#
# This ensures robust generalization under limited compute budgets.

# %% [markdown]
# ### Util Functions

# %%
# !pip install pytorch-msssim
# Out:
# Requirement already satisfied: pytorch-msssim in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from pytorch-msssim) (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->pytorch-msssim) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->pytorch-msssim) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->pytorch-msssim) (3.0.3)

# %%
def freeze_all(model):
    for p in model.parameters():
        p.requires_grad = False

def unfreeze_by_keywords(model, keywords):
    for name, p in model.named_parameters():
        if any(k in name for k in keywords):
            p.requires_grad = True

# %%
from pytorch_msssim import ssim

class SSIMLoss(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, pred, target):
        # expects [0,1] range
        return 1 - ssim(pred, target, data_range=1.0)

class L1Loss(nn.Module):
    def forward(self, pred, tgt):
        return F.l1_loss(pred, tgt)

class ExposureCompositeLoss(nn.Module):
    def __init__(self, lambda_ssim=0.2, lambda_bright=0.1):
        super().__init__()
        self.l1 = nn.L1Loss()
        self.lambda_ssim = lambda_ssim
        self.lambda_bright = lambda_bright

    def forward(self, pred, target):
        l1 = self.l1(pred, target)
        ssim_loss = 1 - ssim(pred, target, data_range=1.0)
        bright = brightness_loss(pred, target)

        return (
            l1
            + self.lambda_ssim * ssim_loss
            + self.lambda_bright * bright
        )

class RestorationLoss(nn.Module):
    def __init__(self, lambda_l1=1.0):
        super().__init__()
        self.l1 = L1Loss()
        self.lambda_l1 = lambda_l1

    def forward(self, pred, tgt):
        return self.lambda_l1 * self.l1(pred, tgt)


def brightness_loss(pred, target):
    pred_l = pred.mean(dim=1)
    tgt_l  = target.mean(dim=1)
    return torch.mean(torch.abs(pred_l - tgt_l))

def psnr(pred, target, eps=1e-8):
    mse = F.mse_loss(pred, target, reduction="mean")
    return 20 * torch.log10(1.0 / torch.sqrt(mse + eps))

def ssim_metric(pred, target):
    return ssim(pred, target, data_range=1.0)

# %%
def get_expert_loss(expert_name):
    if expert_name == "exposure":
        return ExposureCompositeLoss(
        lambda_ssim=0.2,
        lambda_bright=0.1
    )

    elif expert_name in ["lens_blur", "gaussian_blur", "defocus", "motion_blur", "rain", "noise"]:
        return RestorationLoss(lambda_l1=1.0)

    else:
        raise ValueError(f"Unknown expert: {expert_name}")

# %%
# EXPERT CONFIG

EXPERT_NAME = "lens_blur"   # "blur" | "rain" | etc.
PRETRAINED_CKPT = f"pretrained/{EXPERT_NAME}.pth"
SAVE_CKPT = f"checkpoints/{EXPERT_NAME}_curetsd.pth"

# %% [markdown]
# ### Fine-Tuning Configurations

# %%
IMG_SIZE = 256
BATCH_SIZE = 2
ACCUM_STEPS = 4
USE_AMP = True

LR = 2e-4
WEIGHT_DECAY = 1e-2

MAX_EPOCHS = 40
PATIENCE = 6
MIN_DELTA = 0.05
skipped_patience_epochs = 4

MODEL_CFG = dict(
    inp_channels=3,
    out_channels=3,
    dim=48,
    num_blocks=[4, 6, 6, 8],
    num_refinement_blocks=4,
    heads=[1, 2, 4, 8],
    ffn_expansion_factor=2.66
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


model = Restormer(**MODEL_CFG).to(device)
load_restormer_checkpoint(model, PRETRAINED_CKPT, strict=False)

# Stage 1: decoder only
freeze_all(model)
unfreeze_by_keywords(model, ["decoder", "refinement"])

optimizer = torch.optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=LR,
    weight_decay=WEIGHT_DECAY
)

criterion = get_expert_loss(EXPERT_NAME)
scaler = torch.amp.GradScaler("cuda", enabled=USE_AMP)
# Out:
# Loaded pretrained/lens_blur.pth | missing=0 unexpected=0

# %% [markdown]
# ### Fine-Tuning Loop

# %%
best_psnr = 0.0
epochs_no_improve = 0

print(f"Training expert: {EXPERT_NAME}")
print("Stage 1: decoder + refinement only")

for epoch in range(MAX_EPOCHS):

    # -------- STAGE 2 UNFREEZE --------
    if epoch == 10:
        print("Stage 2: unfreeze latent + encoder_level3")
        unfreeze_by_keywords(model, ["latent", "encoder_level3"])
        optimizer = torch.optim.AdamW(
            filter(lambda p: p.requires_grad, model.parameters()),
            lr=LR * 0.5,
            weight_decay=WEIGHT_DECAY
        )

    # -------- TRAIN --------
    model.train()
    running_loss = 0.0
    optimizer.zero_grad(set_to_none=True)

    for batch_idx, batch in enumerate(tqdm(train_loader)):
        inp = batch["input"].to(device, non_blocking=True)
        tgt = batch["target"].to(device, non_blocking=True)

        with torch.amp.autocast("cuda", enabled=USE_AMP):
            pred = model(inp)
            loss = criterion(pred, tgt) / ACCUM_STEPS

        scaler.scale(loss).backward()

        if (batch_idx + 1) % ACCUM_STEPS == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad(set_to_none=True)

        running_loss += loss.item() * ACCUM_STEPS

    train_loss = running_loss / len(train_loader)

    model.eval()

    val_psnr = 0.0
    val_ssim = 0.0

    with torch.no_grad():
        for batch in val_loader:
            inp = batch["input"].to(device, non_blocking=True)
            tgt = batch["target"].to(device, non_blocking=True)

            with torch.amp.autocast("cuda", enabled=USE_AMP):
                pred = model(inp)

            val_psnr += psnr(pred, tgt).item()
            val_ssim += ssim_metric(pred, tgt).item()

    val_psnr /= len(val_loader)
    val_ssim /= len(val_loader)

    print(
        f"[{EXPERT_NAME}] "
        f"Val PSNR: {val_psnr:.2f} dB | "
        f"Val SSIM: {val_ssim:.4f}"
    )


    # -------- EARLY STOPPING --------
    if val_psnr > best_psnr + MIN_DELTA:
        best_psnr = val_psnr
        epochs_no_improve = 0
        torch.save(model.state_dict(), SAVE_CKPT)
        print("Saved best model")
    else:
        if skipped_patience_epochs > epoch+1:
          epochs_no_improve += 1

    if epochs_no_improve >= PATIENCE:
        print("⏹ Early stopping triggered")
        break

    torch.cuda.empty_cache()
# Out:
# Training expert: lens_blur
# Stage 1: decoder + refinement only
# 100%|██████████| 1000/1000 [05:06<00:00,  3.27it/s]
# [lens_blur] Val PSNR: 33.83 dB | Val SSIM: 0.8931
# Saved best model
# 100%|██████████| 1000/1000 [05:06<00:00,  3.26it/s]
# [lens_blur] Val PSNR: 34.07 dB | Val SSIM: 0.8963
# Saved best model
# 100%|██████████| 1000/1000 [05:07<00:00,  3.26it/s]
# [lens_blur] Val PSNR: 33.88 dB | Val SSIM: 0.8942
# 100%|██████████| 1000/1000 [05:06<00:00,  3.26it/s]
# [lens_blur] Val PSNR: 33.94 dB | Val SSIM: 0.8954
# 100%|██████████| 1000/1000 [05:06<00:00,  3.27it/s]
# [lens_blur] Val PSNR: 34.09 dB | Val SSIM: 0.8945
# 100%|██████████| 1000/1000 [05:06<00:00,  3.26it/s]
# [lens_blur] Val PSNR: 34.08 dB | Val SSIM: 0.8962
# 100%|██████████| 1000/1000 [05:06<00:00,  3.26it/s]
# [lens_blur] Val PSNR: 34.04 dB | Val SSIM: 0.8990
# 100%|██████████| 1000/1000 [05:06<00:00,  3.26it/s]
# [lens_blur] Val PSNR: 34.04 dB | Val SSIM: 0.8963
# 100%|██████████| 1000/1000 [05:06<00:00,  3.26it/s]
# [lens_blur] Val PSNR: 34.10 dB | Val SSIM: 0.8941
# 100%|██████████| 1000/1000 [05:07<00:00,  3.26it/s]
# [lens_blur] Val PSNR: 34.11 dB | Val SSIM: 0.9010
# Stage 2: unfreeze latent + encoder_level3
# 100%|██████████| 1000/1000 [05:48<00:00,  2.87it/s]
# [lens_blur] Val PSNR: 34.22 dB | Val SSIM: 0.9020
# Saved best model
# 100%|██████████| 1000/1000 [05:46<00:00,  2.89it/s]
# [lens_blur] Val PSNR: 34.22 dB | Val SSIM: 0.9002
# 100%|██████████| 1000/1000 [05:47<00:00,  2.88it/s]
# [lens_blur] Val PSNR: 34.24 dB | Val SSIM: 0.9028
# 100%|██████████| 1000/1000 [05:46<00:00,  2.89it/s]
# [lens_blur] Val PSNR: 34.14 dB | Val SSIM: 0.8996
# 100%|██████████| 1000/1000 [05:46<00:00,  2.89it/s]
# [lens_blur] Val PSNR: 34.14 dB | Val SSIM: 0.8966
# 100%|██████████| 1000/1000 [05:45<00:00,  2.89it/s]
# [lens_blur] Val PSNR: 34.28 dB | Val SSIM: 0.9006
# Saved best model
#  41%|████      | 408/1000 [02:21<03:26,  2.87it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1409304414.py in <cell line: 0>()
#      30             loss = criterion(pred, tgt) / ACCUM_STEPS
#      31
# ---> 32         scaler.scale(loss).backward()
#      33
#      34         if (batch_idx + 1) % ACCUM_STEPS == 0:
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     839         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840     try:
# --> 841         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842             t_outputs, *args, **kwargs
#     843         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# After an initial phase of fine-tuning, the training process was intentionally interrupted due to Google Colab compute and credit limitations. At this stage, the model had already converged to a stable performance level, and further improvements were observed to be incremental rather than substantial. Given the computational cost of continuing training under constrained resources, it was determined that additional fine-tuning would be more efficiently conducted in a higher-performance hardware environment. Under such conditions, extended training and more advanced optimization strategies could be applied to further refine the model’s performance.

# %% [markdown]
# ## Test-Time Evaluation
#
# During testing:
# - Images are padded to valid dimensions
# - Model outputs are cropped back to original size
# - PSNR and SSIM are computed per image
# - Restored images are saved for inspection
#
# ---
#
# ## Qualitative Visualization
#
# Selected test samples are visualized side by side:
# - Degraded input
# - Restored output
# - Clean ground truth
#
# Quantitative metrics are displayed alongside visual results to correlate numerical performance with perceptual quality.

# %%
from torchvision.utils import save_image

IMG_SIZE = 512   # not used for resize anymore
SAVE_IMAGES = True
SAVE_DIR = "results"
os.makedirs(SAVE_DIR, exist_ok=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Restormer(**MODEL_CFG).to(device)
model.load_state_dict(torch.load(SAVE_CKPT, map_location="cpu"))
model.eval()

psnr_total = 0.0
ssim_total = 0.0
num_samples = 0

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Testing"):
        inp = batch["input"].to(device, non_blocking=True)
        tgt = batch["target"].to(device, non_blocking=True)
        name = batch["name"][0]

        # -------- Pad --------
        inp_pad, (h, w) = pad_to_multiple_of_8(inp)
        tgt_pad, _ = pad_to_multiple_of_8(tgt)

        with torch.amp.autocast("cuda", enabled=USE_AMP):
            pred_pad = model(inp_pad).clamp(0, 1)

        # -------- Unpad --------
        pred = pred_pad[:, :, :h, :w]
        tgt  = tgt[:, :, :h, :w]

        # -------- Metrics --------
        psnr_val = psnr(pred, tgt)
        ssim_val = ssim(pred, tgt)

        psnr_total += psnr_val.item()
        ssim_total += ssim_val.item()
        num_samples += 1

        # -------- Save --------
        if SAVE_IMAGES:
            save_image(pred, os.path.join(SAVE_DIR, name))

        del inp, tgt, inp_pad, pred_pad, pred
        torch.cuda.empty_cache()

print("✅ Test Results")
print(f"PSNR : {psnr_total / num_samples:.2f} dB")
print(f"SSIM : {ssim_total / num_samples:.4f}")
# Out:
# Testing: 100%|██████████| 500/500 [06:23<00:00,  1.30it/s]
# ✅ Test Results
# PSNR : 32.54 dB
# SSIM : 1.0000

# %%
test_iter = iter(test_loader)

# %%
import matplotlib.pyplot as plt
import torch


batch = next(test_iter)

inp = batch["input"].to(device)     # (1,3,H,W)
tgt = batch["target"].to(device)    # (1,3,H,W)
name = batch["name"][0]


# -------- Pad --------
inp_pad, (h, w) = pad_to_multiple_of_8(inp)
tgt_pad, _ = pad_to_multiple_of_8(tgt)



# Model inference

model.eval()
with torch.no_grad():
    with torch.amp.autocast("cuda", enabled=USE_AMP):
        pred_pad = model(inp_pad).clamp(0, 1)

# -------- Unpad --------
pred = pred_pad[:, :, :h, :w]
tgt  = tgt[:, :, :h, :w]


# Metrics
psnr_val = psnr(pred, tgt).item()
ssim_val = ssim(pred, tgt).item()

psnr_inp = psnr(inp, tgt).item()
ssim_inp = ssim(inp, tgt).item()

print(f"Image: {name}")
print(f"PSNR-PRED : {psnr_val:.2f} dB")
print(f"SSIM-PRED : {ssim_val:.4f}")


# Convert tensors to images
inp_img  = inp[0].cpu().permute(1, 2, 0).numpy()
pred_img = pred[0].cpu().permute(1, 2, 0).numpy()
tgt_img  = tgt[0].cpu().permute(1, 2, 0).numpy()


# Visualization
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].imshow(inp_img)
axes[0].set_title("Input (Degraded)")
axes[0].axis("off")

axes[1].imshow(pred_img)
axes[1].set_title(
    f"Restored\nPSNR: {psnr_val:.2f} dB | SSIM: {ssim_val:.4f}"
    + f" PSNR: {psnr_inp:.2f} dB | SSIM: {ssim_inp:.4f}"
)
axes[1].axis("off")

axes[2].imshow(tgt_img)
axes[2].set_title("Ground Truth")
axes[2].axis("off")

plt.suptitle(name, fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Image: 01_21_02_02_009.jpg
# PSNR-PRED : 29.81 dB
# SSIM-PRED : 1.0000

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !zip -r lens_blur_results.zip results/
# Out:
#   adding: results/ (stored 0%)
#   adding: results/01_39_02_02_277.jpg (deflated 1%)
#   adding: results/01_39_02_01_194.jpg (deflated 2%)
#   adding: results/01_39_02_01_291.jpg (deflated 1%)
#   adding: results/01_19_02_02_191.jpg (deflated 1%)
#   adding: results/01_24_02_02_058.jpg (deflated 1%)
#   adding: results/01_21_02_01_146.jpg (deflated 1%)
#   adding: results/01_31_02_01_227.jpg (deflated 2%)
#   adding: results/01_31_02_02_161.jpg (deflated 1%)
#   adding: results/01_06_02_02_208.jpg (deflated 1%)
#   adding: results/01_05_02_02_080.jpg (deflated 1%)
#   adding: results/01_04_02_02_016.jpg (deflated 1%)
#   adding: results/01_08_02_02_210.jpg (deflated 1%)
#   adding: results/01_24_02_02_133.jpg (deflated 2%)
#   adding: results/01_38_02_02_300.jpg (deflated 1%)
#   adding: results/01_24_02_01_054.jpg (deflated 1%)
#   adding: results/01_21_02_02_005.jpg (deflated 1%)
#   adding: results/01_08_02_01_277.jpg (deflated 0%)
#   adding: results/01_31_02_02_209.jpg (deflated 2%)
#   adding: results/01_21_02_02_150.jpg (deflated 1%)
#   adding: results/01_21_02_02_257.jpg (deflated 1%)
#   adding: results/01_47_02_01_274.jpg (deflated 0%)
#   adding: results/01_18_02_01_055.jpg (deflated 0%)
#   adding: results/01_41_02_02_208.jpg (deflated 3%)
#   adding: results/01_39_02_02_056.jpg (deflated 2%)
#   adding: results/01_05_02_02_049.jpg (deflated 1%)
#   adding: results/01_07_02_01_196.jpg (deflated 1%)
#   adding: results/01_07_02_01_078.jpg (deflated 0%)
#   adding: results/01_41_02_01_151.jpg (deflated 2%)
#   adding: results/01_41_02_01_156.jpg (deflated 2%)
#   adding: results/01_04_02_01_167.jpg (deflated 2%)
#   adding: results/01_06_02_01_217.jpg (deflated 1%)
#   adding: results/01_06_02_02_106.jpg (deflated 2%)
#   adding: results/01_21_02_02_202.jpg (deflated 1%)
#   adding: results/01_41_02_02_022.jpg (deflated 2%)
#   adding: results/01_26_02_02_016.jpg (deflated 0%)
#   adding: results/01_31_02_02_189.jpg (deflated 2%)
#   adding: results/01_06_02_01_033.jpg (deflated 1%)
#   adding: results/01_07_02_02_017.jpg (deflated 1%)
#   adding: results/01_26_02_02_045.jpg (deflated 0%)
#   adding: results/01_08_02_02_213.jpg (deflated 1%)
#   adding: results/01_24_02_02_180.jpg (deflated 1%)
#   adding: results/01_24_02_02_272.jpg (deflated 0%)
#   adding: results/01_08_02_02_254.jpg (deflated 0%)
#   adding: results/01_31_02_01_162.jpg (deflated 1%)
#   adding: results/01_21_02_02_067.jpg (deflated 1%)
#   adding: results/01_05_02_02_060.jpg (deflated 1%)
#   adding: results/01_24_02_02_205.jpg (deflated 1%)
#   adding: results/01_07_02_01_247.jpg (deflated 1%)
#   adding: results/01_39_02_02_177.jpg (deflated 2%)
#   adding: results/01_38_02_01_250.jpg (deflated 1%)
#   adding: results/01_08_02_02_290.jpg (deflated 0%)
#   adding: results/01_21_02_02_027.jpg (deflated 1%)
#   adding: results/01_26_02_01_281.jpg (deflated 2%)
#   adding: results/01_04_02_02_022.jpg (deflated 1%)
#   adding: results/01_05_02_02_012.jpg (deflated 1%)
#   adding: results/01_21_02_01_004.jpg (deflated 1%)
#   adding: results/01_21_02_02_149.jpg (deflated 1%)
#   adding: results/01_38_02_02_299.jpg (deflated 1%)
#   adding: results/01_31_02_02_235.jpg (deflated 2%)
#   adding: results/01_18_02_01_087.jpg (deflated 1%)
#   adding: results/01_07_02_01_253.jpg (deflated 1%)
#   adding: results/01_24_02_01_200.jpg (deflated 1%)
#   adding: results/01_21_02_01_179.jpg (deflated 1%)
#   adding: results/01_24_02_01_199.jpg (deflated 1%)
#   adding: results/01_18_02_01_073.jpg (deflated 0%)
#   adding: results/01_06_02_01_040.jpg (deflated 1%)
#   adding: results/01_26_02_01_283.jpg (deflated 3%)
#   adding: results/01_31_02_01_209.jpg (deflated 1%)
#   adding: results/01_07_02_01_245.jpg (deflated 1%)
#   adding: results/01_26_02_02_259.jpg (deflated 2%)
#   adding: results/01_21_02_02_011.jpg (deflated 1%)
#   adding: results/01_06_02_02_114.jpg (deflated 2%)
#   adding: results/01_41_02_02_202.jpg (deflated 3%)
#   adding: results/01_05_02_02_053.jpg (deflated 1%)
#   adding: results/01_24_02_01_125.jpg (deflated 1%)
#   adding: results/01_41_02_01_276.jpg (deflated 2%)
#   adding: results/01_08_02_02_257.jpg (deflated 0%)
#   adding: results/01_26_02_02_026.jpg (deflated 1%)
#   adding: results/01_08_02_01_269.jpg (deflated 0%)
#   adding: results/01_24_02_01_134.jpg (deflated 2%)
#   adding: results/01_26_02_01_260.jpg (deflated 2%)
#   adding: results/01_18_02_01_071.jpg (deflated 0%)
#   adding: results/01_26_02_02_035.jpg (deflated 1%)
#   adding: results/01_26_02_02_257.jpg (deflated 2%)
#   adding: results/01_18_02_01_092.jpg (deflated 1%)
#   adding: results/01_24_02_01_074.jpg (deflated 1%)
#   adding: results/01_21_02_02_165.jpg (deflated 1%)
#   adding: results/01_31_02_02_210.jpg (deflated 1%)
#   adding: results/01_47_02_02_263.jpg (deflated 0%)
#   adding: results/01_06_02_02_183.jpg (deflated 1%)
#   adding: results/01_06_02_01_073.jpg (deflated 2%)
#   adding: results/01_31_02_02_229.jpg (deflated 2%)
#   adding: results/01_21_02_02_286.jpg (deflated 1%)
#   adding: results/01_21_02_02_094.jpg (deflated 1%)
#   adding: results/01_08_02_01_217.jpg (deflated 1%)
#   adding: results/01_24_02_01_018.jpg (deflated 0%)
#   adding: results/01_21_02_02_059.jpg (deflated 1%)
#   adding: results/01_24_02_01_204.jpg (deflated 1%)
#   adding: results/01_21_02_01_166.jpg (deflated 1%)
#   adding: results/01_21_02_01_119.jpg (deflated 1%)
#   adding: results/01_26_02_02_238.jpg (deflated 2%)
#   adding: results/01_18_02_02_047.jpg (deflated 1%)
#   adding: results/01_21_02_02_133.jpg (deflated 1%)
#   adding: results/01_06_02_02_123.jpg (deflated 2%)
#   adding: results/01_41_02_02_197.jpg (deflated 2%)
#   adding: results/01_24_02_01_052.jpg (deflated 1%)
#   adding: results/01_39_02_01_267.jpg (deflated 1%)
#   adding: results/01_04_02_02_127.jpg (deflated 0%)
#   adding: results/01_08_02_02_271.jpg (deflated 0%)
#   adding: results/01_39_02_02_269.jpg (deflated 1%)
#   adding: results/01_21_02_01_199.jpg (deflated 1%)
#   adding: results/01_07_02_01_187.jpg (deflated 1%)
#   adding: results/01_47_02_02_273.jpg (deflated 0%)
#   adding: results/01_08_02_01_234.jpg (deflated 1%)
#   adding: results/01_26_02_01_251.jpg (deflated 2%)
#   adding: results/01_39_02_02_112.jpg (deflated 2%)
#   adding: results/01_07_02_02_237.jpg (deflated 1%)
#   adding: results/01_31_02_02_299.jpg (deflated 1%)
#   adding: results/01_47_02_01_270.jpg (deflated 0%)
#   adding: results/01_38_02_02_239.jpg (deflated 2%)
#   adding: results/01_21_02_02_077.jpg (deflated 1%)
#   adding: results/01_18_02_01_076.jpg (deflated 0%)
#   adding: results/01_21_02_01_058.jpg (deflated 1%)
#   adding: results/01_39_02_02_168.jpg (deflated 2%)
#   adding: results/01_04_02_01_027.jpg (deflated 1%)
#   adding: results/01_38_02_01_211.jpg (deflated 1%)
#   adding: results/01_41_02_01_013.jpg (deflated 2%)
#   adding: results/01_06_02_02_103.jpg (deflated 2%)
#   adding: results/01_18_02_02_095.jpg (deflated 1%)
#   adding: results/01_07_02_01_286.jpg (deflated 2%)
#   adding: results/01_41_02_01_182.jpg (deflated 2%)
#   adding: results/01_24_02_02_106.jpg (deflated 1%)
#   adding: results/01_08_02_01_001.jpg (deflated 1%)
#   adding: results/01_24_02_02_052.jpg (deflated 1%)
#   adding: results/01_07_02_02_073.jpg (deflated 0%)
#   adding: results/01_07_02_01_287.jpg (deflated 2%)
#   adding: results/01_26_02_02_284.jpg (deflated 3%)
#   adding: results/01_39_02_02_245.jpg (deflated 1%)
#   adding: results/01_08_02_01_164.jpg (deflated 1%)
#   adding: results/01_07_02_01_172.jpg (deflated 1%)
#   adding: results/01_21_02_02_276.jpg (deflated 1%)
#   adding: results/01_38_02_01_265.jpg (deflated 1%)
#   adding: results/01_21_02_01_034.jpg (deflated 1%)
#   adding: results/01_24_02_02_203.jpg (deflated 1%)
#   adding: results/01_06_02_01_048.jpg (deflated 1%)
#   adding: results/01_24_02_02_191.jpg (deflated 1%)
#   adding: results/01_24_02_01_167.jpg (deflated 2%)
#   adding: results/01_41_02_02_243.jpg (deflated 3%)
#   adding: results/01_26_02_02_229.jpg (deflated 2%)
#   adding: results/01_24_02_02_002.jpg (deflated 1%)
#   adding: results/01_41_02_02_176.jpg (deflated 2%)
#   adding: results/01_08_02_01_272.jpg (deflated 0%)
#   adding: results/01_41_02_02_238.jpg (deflated 3%)
#   adding: results/01_38_02_02_254.jpg (deflated 2%)
#   adding: results/01_08_02_02_198.jpg (deflated 1%)
#   adding: results/01_08_02_01_200.jpg (deflated 1%)
#   adding: results/01_07_02_01_048.jpg (deflated 1%)
#   adding: results/01_31_02_02_230.jpg (deflated 2%)
#   adding: results/01_38_02_01_237.jpg (deflated 2%)
#   adding: results/01_41_02_01_287.jpg (deflated 1%)
#   adding: results/01_07_02_01_249.jpg (deflated 1%)
#   adding: results/01_07_02_02_248.jpg (deflated 1%)
#   adding: results/01_21_02_02_164.jpg (deflated 1%)
#   adding: results/01_21_02_01_257.jpg (deflated 1%)
#   adding: results/01_41_02_01_164.jpg (deflated 2%)
#   adding: results/01_05_02_02_022.jpg (deflated 1%)
#   adding: results/01_24_02_02_113.jpg (deflated 1%)
#   adding: results/01_41_02_01_017.jpg (deflated 2%)
#   adding: results/01_41_02_02_227.jpg (deflated 3%)
#   adding: results/01_07_02_02_066.jpg (deflated 1%)
#   adding: results/01_41_02_02_132.jpg (deflated 2%)
#   adding: results/01_04_02_01_173.jpg (deflated 2%)
#   adding: results/01_39_02_02_254.jpg (deflated 2%)
#   adding: results/01_21_02_02_115.jpg (deflated 1%)
#   adding: results/01_31_02_01_220.jpg (deflated 2%)
#   adding: results/01_08_02_02_215.jpg (deflated 1%)
#   adding: results/01_06_02_02_216.jpg (deflated 1%)
#   adding: results/01_21_02_02_148.jpg (deflated 1%)
#   adding: results/01_24_02_01_122.jpg (deflated 1%)
#   adding: results/01_41_02_02_139.jpg (deflated 2%)
#   adding: results/01_08_02_02_214.jpg (deflated 1%)
#   adding: results/01_26_02_02_245.jpg (deflated 2%)
#   adding: results/01_26_02_02_043.jpg (deflated 0%)
#   adding: results/01_41_02_02_164.jpg (deflated 2%)
#   adding: results/01_06_02_02_147.jpg (deflated 2%)
#   adding: results/01_39_02_01_172.jpg (deflated 2%)
#   adding: results/01_06_02_02_251.jpg (deflated 1%)
#   adding: results/01_38_02_02_286.jpg (deflated 1%)
#   adding: results/01_04_02_01_169.jpg (deflated 2%)
#   adding: results/01_06_02_02_041.jpg (deflated 1%)
#   adding: results/01_06_02_02_127.jpg (deflated 2%)
#   adding: results/01_41_02_02_178.jpg (deflated 2%)
#   adding: results/01_26_02_01_265.jpg (deflated 2%)
#   adding: results/01_21_02_02_239.jpg (deflated 2%)
#   adding: results/01_24_02_01_076.jpg (deflated 1%)
#   adding: results/01_26_02_02_013.jpg (deflated 0%)
#   adding: results/01_08_02_01_246.jpg (deflated 1%)
#   adding: results/01_26_02_01_048.jpg (deflated 0%)
#   adding: results/01_26_02_01_037.jpg (deflated 0%)
#   adding: results/01_21_02_01_185.jpg (deflated 1%)
#   adding: results/01_21_02_01_224.jpg (deflated 1%)
#   adding: results/01_21_02_02_004.jpg (deflated 1%)
#   adding: results/01_24_02_01_184.jpg (deflated 1%)
#   adding: results/01_26_02_01_025.jpg (deflated 0%)
#   adding: results/01_24_02_02_198.jpg (deflated 1%)
#   adding: results/01_08_02_02_166.jpg (deflated 1%)
#   adding: results/01_26_02_02_289.jpg (deflated 3%)
#   adding: results/01_05_02_01_043.jpg (deflated 1%)
#   adding: results/01_41_02_02_255.jpg (deflated 2%)
#   adding: results/01_21_02_02_218.jpg (deflated 1%)
#   adding: results/01_08_02_02_273.jpg (deflated 0%)
#   adding: results/01_38_02_01_288.jpg (deflated 1%)
#   adding: results/01_21_02_02_162.jpg (deflated 1%)
#   adding: results/01_08_02_01_261.jpg (deflated 0%)
#   adding: results/01_18_02_01_002.jpg (deflated 2%)
#   adding: results/01_07_02_02_295.jpg (deflated 1%)
#   adding: results/01_21_02_01_206.jpg (deflated 1%)
#   adding: results/01_21_02_02_013.jpg (deflated 1%)
#   adding: results/01_38_02_02_215.jpg (deflated 2%)
#   adding: results/01_38_02_01_296.jpg (deflated 1%)
#   adding: results/01_39_02_01_206.jpg (deflated 2%)
#   adding: results/01_38_02_02_211.jpg (deflated 2%)
#   adding: results/01_05_02_01_077.jpg (deflated 1%)
#   adding: results/01_26_02_01_278.jpg (deflated 3%)
#   adding: results/01_21_02_01_264.jpg (deflated 1%)
#   adding: results/01_39_02_02_194.jpg (deflated 2%)
#   adding: results/01_41_02_01_237.jpg (deflated 3%)
#   adding: results/01_21_02_02_083.jpg (deflated 1%)
#   adding: results/01_07_02_02_051.jpg (deflated 1%)
#   adding: results/01_26_02_01_014.jpg (deflated 0%)
#   adding: results/01_06_02_01_203.jpg (deflated 1%)
#   adding: results/01_41_02_02_230.jpg (deflated 3%)
#   adding: results/01_05_02_02_040.jpg (deflated 1%)
#   adding: results/01_31_02_01_234.jpg (deflated 2%)
#   adding: results/01_39_02_02_105.jpg (deflated 2%)
#   adding: results/01_08_02_01_227.jpg (deflated 1%)
#   adding: results/01_21_02_02_139.jpg (deflated 1%)
#   adding: results/01_06_02_01_128.jpg (deflated 2%)
#   adding: results/01_26_02_01_018.jpg (deflated 0%)
#   adding: results/01_24_02_01_019.jpg (deflated 0%)
#   adding: results/01_08_02_02_163.jpg (deflated 1%)
#   adding: results/01_06_02_02_175.jpg (deflated 1%)
#   adding: results/01_08_02_01_248.jpg (deflated 1%)
#   adding: results/01_39_02_02_163.jpg (deflated 2%)
#   adding: results/01_06_02_01_137.jpg (deflated 2%)
#   adding: results/01_24_02_01_150.jpg (deflated 2%)
#   adding: results/01_41_02_02_177.jpg (deflated 3%)
#   adding: results/01_26_02_01_035.jpg (deflated 0%)
#   adding: results/01_07_02_01_004.jpg (deflated 1%)
#   adding: results/01_41_02_01_126.jpg (deflated 2%)
#   adding: results/01_24_02_02_154.jpg (deflated 2%)
#   adding: results/01_26_02_02_261.jpg (deflated 2%)
#   adding: results/01_07_02_02_230.jpg (deflated 1%)
#   adding: results/01_41_02_02_254.jpg (deflated 2%)
#   adding: results/01_04_02_02_034.jpg (deflated 1%)
#   adding: results/01_39_02_02_278.jpg (deflated 1%)
#   adding: results/01_24_02_02_214.jpg (deflated 1%)
#   adding: results/01_07_02_02_171.jpg (deflated 1%)
#   adding: results/01_06_02_01_222.jpg (deflated 1%)
#   adding: results/01_06_02_01_049.jpg (deflated 1%)
#   adding: results/01_04_02_01_135.jpg (deflated 0%)
#   adding: results/01_21_02_02_269.jpg (deflated 1%)
#   adding: results/01_07_02_02_018.jpg (deflated 1%)
#   adding: results/01_24_02_01_086.jpg (deflated 1%)
#   adding: results/01_05_02_02_051.jpg (deflated 1%)
#   adding: results/01_26_02_02_033.jpg (deflated 1%)
#   adding: results/01_21_02_02_107.jpg (deflated 1%)
#   adding: results/01_08_02_02_015.jpg (deflated 1%)
#   adding: results/01_24_02_02_096.jpg (deflated 1%)
#   adding: results/01_31_02_01_213.jpg (deflated 1%)
#   adding: results/01_06_02_01_078.jpg (deflated 2%)
#   adding: results/01_19_02_02_199.jpg (deflated 1%)
#   adding: results/01_41_02_01_192.jpg (deflated 1%)
#   adding: results/01_26_02_01_034.jpg (deflated 1%)
#   adding: results/01_38_02_01_274.jpg (deflated 1%)
#   adding: results/01_08_02_02_180.jpg (deflated 1%)
#   adding: results/01_47_02_02_254.jpg (deflated 0%)
#   adding: results/01_41_02_02_248.jpg (deflated 2%)
#   adding: results/01_06_02_01_210.jpg (deflated 1%)
#   adding: results/01_39_02_02_193.jpg (deflated 2%)
#   adding: results/01_07_02_02_181.jpg (deflated 1%)
#   adding: results/01_08_02_02_184.jpg (deflated 1%)
#   adding: results/01_21_02_01_259.jpg (deflated 1%)
#   adding: results/01_39_02_01_258.jpg (deflated 2%)
#   adding: results/01_07_02_01_231.jpg (deflated 1%)
#   adding: results/01_21_02_01_003.jpg (deflated 1%)
#   adding: results/01_39_02_02_195.jpg (deflated 2%)
#   adding: results/01_08_02_02_283.jpg (deflated 0%)
#   adding: results/01_21_02_01_167.jpg (deflated 1%)
#   adding: results/01_38_02_01_199.jpg (deflated 2%)
#   adding: results/01_05_02_02_085.jpg (deflated 2%)
#   adding: results/01_21_02_01_153.jpg (deflated 1%)
#   adding: results/01_21_02_02_060.jpg (deflated 1%)
#   adding: results/01_06_02_02_118.jpg (deflated 2%)
#   adding: results/01_06_02_01_088.jpg (deflated 2%)
#   adding: results/01_06_02_02_083.jpg (deflated 2%)
#   adding: results/01_26_02_01_250.jpg (deflated 2%)
#   adding: results/01_41_02_01_123.jpg (deflated 2%)
#   adding: results/01_07_02_01_068.jpg (deflated 1%)
#   adding: results/01_04_02_01_022.jpg (deflated 1%)
#   adding: results/01_21_02_02_264.jpg (deflated 1%)
#   adding: results/01_47_02_02_252.jpg (deflated 0%)
#   adding: results/01_39_02_02_161.jpg (deflated 2%)
#   adding: results/01_06_02_01_236.jpg (deflated 1%)
#   adding: results/01_41_02_01_242.jpg (deflated 2%)
#   adding: results/01_07_02_02_082.jpg (deflated 0%)
#   adding: results/01_05_02_01_012.jpg (deflated 1%)
#   adding: results/01_06_02_02_068.jpg (deflated 2%)
#   adding: results/01_31_02_01_150.jpg (deflated 1%)
#   adding: results/01_19_02_02_229.jpg (deflated 0%)
#   adding: results/01_04_02_02_043.jpg (deflated 1%)
#   adding: results/01_06_02_02_064.jpg (deflated 1%)
#   adding: results/01_18_02_02_093.jpg (deflated 1%)
#   adding: results/01_08_02_01_250.jpg (deflated 0%)
#   adding: results/01_07_02_02_008.jpg (deflated 1%)
#   adding: results/01_08_02_02_243.jpg (deflated 1%)
#   adding: results/01_41_02_02_224.jpg (deflated 3%)
#   adding: results/01_19_02_01_214.jpg (deflated 1%)
#   adding: results/01_21_02_02_010.jpg (deflated 1%)
#   adding: results/01_39_02_01_283.jpg (deflated 1%)
#   adding: results/01_39_02_02_063.jpg (deflated 2%)
#   adding: results/01_26_02_02_020.jpg (deflated 0%)
#   adding: results/01_26_02_01_046.jpg (deflated 0%)
#   adding: results/01_18_02_02_045.jpg (deflated 1%)
#   adding: results/01_07_02_02_211.jpg (deflated 1%)
#   adding: results/01_26_02_02_282.jpg (deflated 4%)
#   adding: results/01_41_02_01_281.jpg (deflated 1%)
#   adding: results/01_04_02_02_129.jpg (deflated 0%)
#   adding: results/01_06_02_02_190.jpg (deflated 1%)
#   adding: results/01_21_02_01_138.jpg (deflated 1%)
#   adding: results/01_39_02_01_251.jpg (deflated 1%)
#   adding: results/01_06_02_01_138.jpg (deflated 2%)
#   adding: results/01_26_02_01_041.jpg (deflated 0%)
#   adding: results/01_18_02_02_064.jpg (deflated 0%)
#   adding: results/01_31_02_01_173.jpg (deflated 1%)
#   adding: results/01_24_02_02_085.jpg (deflated 1%)
#   adding: results/01_26_02_02_252.jpg (deflated 2%)
#   adding: results/01_39_02_02_261.jpg (deflated 1%)
#   adding: results/01_26_02_01_028.jpg (deflated 1%)
#   adding: results/01_07_02_01_181.jpg (deflated 1%)
#   adding: results/01_06_02_02_082.jpg (deflated 2%)
#   adding: results/01_39_02_02_178.jpg (deflated 2%)
#   adding: results/01_06_02_01_031.jpg (deflated 1%)
#   adding: results/01_24_02_01_144.jpg (deflated 2%)
#   adding: results/01_26_02_01_252.jpg (deflated 2%)
#   adding: results/01_24_02_01_120.jpg (deflated 1%)
#   adding: results/01_38_02_02_282.jpg (deflated 2%)
#   adding: results/01_24_02_01_094.jpg (deflated 1%)
#   adding: results/01_07_02_02_222.jpg (deflated 2%)
#   adding: results/01_07_02_02_278.jpg (deflated 2%)
#   adding: results/01_41_02_02_280.jpg (deflated 2%)
#   adding: results/01_18_02_01_003.jpg (deflated 2%)
#   adding: results/01_04_02_01_045.jpg (deflated 2%)
#   adding: results/01_39_02_01_141.jpg (deflated 2%)
#   adding: results/01_26_02_02_267.jpg (deflated 3%)
#   adding: results/01_21_02_02_096.jpg (deflated 1%)
#   adding: results/01_07_02_02_087.jpg (deflated 0%)
#   adding: results/01_21_02_01_150.jpg (deflated 1%)
#   adding: results/01_19_02_02_219.jpg (deflated 0%)
#   adding: results/01_26_02_01_021.jpg (deflated 0%)
#   adding: results/01_41_02_02_232.jpg (deflated 3%)
#   adding: results/01_24_02_02_104.jpg (deflated 1%)
#   adding: results/01_39_02_02_133.jpg (deflated 3%)
#   adding: results/01_06_02_02_231.jpg (deflated 1%)
#   adding: results/01_06_02_01_245.jpg (deflated 1%)
#   adding: results/01_05_02_02_028.jpg (deflated 1%)
#   adding: results/01_21_02_01_215.jpg (deflated 1%)
#   adding: results/01_41_02_02_159.jpg (deflated 2%)
#   adding: results/01_39_02_01_209.jpg (deflated 2%)
#   adding: results/01_08_02_01_167.jpg (deflated 1%)
#   adding: results/01_24_02_01_128.jpg (deflated 1%)
#   adding: results/01_38_02_02_226.jpg (deflated 2%)
#   adding: results/01_31_02_02_199.jpg (deflated 2%)
#   adding: results/01_39_02_02_170.jpg (deflated 2%)
#   adding: results/01_41_02_01_014.jpg (deflated 2%)
#   adding: results/01_06_02_02_218.jpg (deflated 1%)
#   adding: results/01_19_02_01_201.jpg (deflated 1%)
#   adding: results/01_41_02_02_233.jpg (deflated 3%)
#   adding: results/01_08_02_02_219.jpg (deflated 1%)
#   adding: results/01_26_02_02_234.jpg (deflated 2%)
#   adding: results/01_26_02_01_054.jpg (deflated 0%)
#   adding: results/01_08_02_02_020.jpg (deflated 1%)
#   adding: results/01_21_02_02_009.jpg (deflated 1%)
#   adding: results/01_41_02_01_272.jpg (deflated 2%)
#   adding: results/01_21_02_01_088.jpg (deflated 1%)
#   adding: results/01_41_02_01_279.jpg (deflated 1%)
#   adding: results/01_26_02_01_228.jpg (deflated 2%)
#   adding: results/01_21_02_01_266.jpg (deflated 1%)
#   adding: results/01_21_02_01_186.jpg (deflated 1%)
#   adding: results/01_21_02_01_124.jpg (deflated 1%)
#   adding: results/01_04_02_02_044.jpg (deflated 2%)
#   adding: results/01_07_02_02_013.jpg (deflated 1%)
#   adding: results/01_06_02_02_073.jpg (deflated 2%)
#   adding: results/01_38_02_01_267.jpg (deflated 1%)
#   adding: results/01_24_02_02_017.jpg (deflated 0%)
#   adding: results/01_39_02_02_114.jpg (deflated 2%)
#   adding: results/01_24_02_01_047.jpg (deflated 1%)
#   adding: results/01_31_02_02_162.jpg (deflated 1%)
#   adding: results/01_06_02_01_120.jpg (deflated 2%)
#   adding: results/01_24_02_02_083.jpg (deflated 1%)
#   adding: results/01_06_02_01_140.jpg (deflated 2%)
#   adding: results/01_06_02_02_129.jpg (deflated 2%)
#   adding: results/01_41_02_01_189.jpg (deflated 2%)
#   adding: results/01_08_02_01_273.jpg (deflated 0%)
#   adding: results/01_08_02_02_206.jpg (deflated 1%)
#   adding: results/01_39_02_02_098.jpg (deflated 2%)
#   adding: results/01_07_02_01_214.jpg (deflated 1%)
#   adding: results/01_19_02_01_236.jpg (deflated 0%)
#   adding: results/01_24_02_01_082.jpg (deflated 1%)
#   adding: results/01_26_02_01_009.jpg (deflated 0%)
#   adding: results/01_06_02_01_191.jpg (deflated 1%)
#   adding: results/01_07_02_01_067.jpg (deflated 1%)
#   adding: results/01_38_02_01_202.jpg (deflated 2%)
#   adding: results/01_41_02_01_224.jpg (deflated 3%)
#   adding: results/01_06_02_02_086.jpg (deflated 2%)
#   adding: results/01_21_02_01_030.jpg (deflated 1%)
#   adding: results/01_38_02_02_237.jpg (deflated 2%)
#   adding: results/01_21_02_01_286.jpg (deflated 1%)
#   adding: results/01_21_02_01_226.jpg (deflated 1%)
#   adding: results/01_24_02_02_210.jpg (deflated 1%)
#   adding: results/01_21_02_02_281.jpg (deflated 1%)
#   adding: results/01_24_02_02_159.jpg (deflated 2%)
#   adding: results/01_19_02_01_230.jpg (deflated 0%)
#   adding: results/01_05_02_01_014.jpg (deflated 1%)
#   adding: results/01_05_02_01_052.jpg (deflated 1%)
#   adding: results/01_06_02_01_036.jpg (deflated 1%)
#   adding: results/01_08_02_01_212.jpg (deflated 1%)
#   adding: results/01_31_02_02_232.jpg (deflated 2%)
#   adding: results/01_07_02_01_178.jpg (deflated 1%)
#   adding: results/01_41_02_02_241.jpg (deflated 2%)
#   adding: results/01_26_02_02_266.jpg (deflated 2%)
#   adding: results/01_26_02_01_229.jpg (deflated 2%)
#   adding: results/01_21_02_02_201.jpg (deflated 1%)
#   adding: results/01_08_02_02_232.jpg (deflated 1%)
#   adding: results/01_31_02_02_152.jpg (deflated 1%)
#   adding: results/01_26_02_01_062.jpg (deflated 1%)
#   adding: results/01_18_02_02_044.jpg (deflated 1%)
#   adding: results/01_39_02_01_146.jpg (deflated 2%)
#   adding: results/01_26_02_01_258.jpg (deflated 2%)
#   adding: results/01_24_02_02_128.jpg (deflated 1%)
#   adding: results/01_24_02_02_073.jpg (deflated 1%)
#   adding: results/01_26_02_02_290.jpg (deflated 3%)
#   adding: results/01_31_02_02_221.jpg (deflated 2%)
#   adding: results/01_24_02_01_097.jpg (deflated 1%)
#   adding: results/01_18_02_02_068.jpg (deflated 0%)
#   adding: results/01_31_02_02_167.jpg (deflated 1%)
#   adding: results/01_21_02_02_173.jpg (deflated 1%)
#   adding: results/01_21_02_01_042.jpg (deflated 1%)
#   adding: results/01_06_02_02_221.jpg (deflated 1%)
#   adding: results/01_07_02_01_169.jpg (deflated 1%)
#   adding: results/01_39_02_01_100.jpg (deflated 2%)
#   adding: results/01_39_02_02_065.jpg (deflated 2%)
#   adding: results/01_26_02_01_287.jpg (deflated 3%)
#   adding: results/01_06_02_02_234.jpg (deflated 1%)
#   adding: results/01_24_02_01_008.jpg (deflated 1%)
#   adding: results/01_24_02_01_088.jpg (deflated 1%)
#   adding: results/01_39_02_02_151.jpg (deflated 2%)
#   adding: results/01_39_02_02_055.jpg (deflated 2%)
#   adding: results/01_08_02_01_206.jpg (deflated 1%)
#   adding: results/01_39_02_02_153.jpg (deflated 2%)
#   adding: results/01_21_02_01_102.jpg (deflated 1%)
#   adding: results/01_04_02_01_134.jpg (deflated 0%)
#   adding: results/01_24_02_01_101.jpg (deflated 1%)
#   adding: results/01_24_02_02_091.jpg (deflated 1%)
#   adding: results/01_21_02_01_164.jpg (deflated 1%)
#   adding: results/01_06_02_01_192.jpg (deflated 1%)
#   adding: results/01_41_02_01_186.jpg (deflated 2%)
#   adding: results/01_07_02_02_177.jpg (deflated 1%)
#   adding: results/01_31_02_02_192.jpg (deflated 2%)
#   adding: results/01_39_02_01_167.jpg (deflated 2%)
#   adding: results/01_39_02_01_245.jpg (deflated 1%)
#   adding: results/01_06_02_01_142.jpg (deflated 2%)
#   adding: results/01_21_02_01_242.jpg (deflated 1%)
#   adding: results/01_08_02_01_215.jpg (deflated 1%)
#   adding: results/01_21_02_01_072.jpg (deflated 1%)
#   adding: results/01_21_02_02_127.jpg (deflated 1%)
#   adding: results/01_06_02_02_196.jpg (deflated 1%)
#   adding: results/01_24_02_01_287.jpg (deflated 0%)
#   adding: results/01_38_02_02_287.jpg (deflated 1%)
#   adding: results/01_04_02_02_001.jpg (deflated 1%)
#   adding: results/01_08_02_01_170.jpg (deflated 1%)
#   adding: results/01_05_02_02_061.jpg (deflated 1%)
#   adding: results/01_39_02_02_119.jpg (deflated 2%)
#   adding: results/01_41_02_01_174.jpg (deflated 2%)
#   adding: results/01_21_02_01_246.jpg (deflated 1%)
#   adding: results/01_06_02_02_053.jpg (deflated 1%)
#   adding: results/01_06_02_01_076.jpg (deflated 2%)
#   adding: results/01_24_02_01_290.jpg (deflated 0%)
#   adding: results/01_26_02_02_054.jpg (deflated 0%)
#   adding: results/01_26_02_01_051.jpg (deflated 0%)
#   adding: results/01_06_02_02_101.jpg (deflated 2%)
#   adding: results/01_21_02_02_178.jpg (deflated 1%)
#   adding: results/01_21_02_02_062.jpg (deflated 1%)
#   adding: results/01_07_02_02_191.jpg (deflated 1%)
#   adding: results/01_39_02_02_158.jpg (deflated 2%)
#   adding: results/01_41_02_01_212.jpg (deflated 3%)
#   adding: results/01_41_02_02_264.jpg (deflated 2%)
#   adding: results/01_08_02_01_223.jpg (deflated 1%)
#   adding: results/01_18_02_01_070.jpg (deflated 0%)
#   adding: results/01_24_02_02_088.jpg (deflated 1%)

# %%
# !cp lens_blur_results.zip /content/drive/MyDrive/

# %%
# !cp checkpoints/lens_blur_curetsd.pth /content/drive/MyDrive/
